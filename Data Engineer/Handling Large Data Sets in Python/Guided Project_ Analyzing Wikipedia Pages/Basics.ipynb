# %% [markdown]
# # Analyzing Wikipedia Pages
#
# In this guided project, you'll be working with data scraped from Wikipedia, a popular online encyclopedia. Wikipedia is maintained by volunteer content contributors and editors who continuously improve content. Anyone can edit Wikipedia, and you can read more about how to make an edit here. Because Wikipedia is crowdsourced, it's been able to rapidly assemble a huge library of articles.

# %% [markdown]
# ## Introducing Wikipedia Data
#
# * List all of the files in the wiki folder.
# * Count up and display the number of files in the wiki folder.
# * Display a single file from the wiki folder, and look at the raw HTML. Do you see any patterns?

# %%
import pandas as pd
import os

os.listdir("wiki")
# Out:
# ['Furubira_District,_Hokkaido.html',
#  'Valentin_Yanin.html',
#  'Kings_XI_Punjab_in_2014.html',
#  'William_Harvey_Lillard.html',
#  'Radial_Road_3.html',
#  'George_Weldrick.html',
#  'Zgornji_Otok.html',
#  'Blue_Heelers_(season_8).html',
#  'Taggen_Nunatak.html',
#  '1951_National_League_tie-breaker_series.html',
#  'List_of_number-one_singles_of_1993_(Finland).html',
#  'Vrila.html',
#  'William_Henry_Porter.html',
#  'Clive_Brown_(footballer).html',
#  '2010_Karshi_Challenger_%E2%80%93_Singles.html',
#  'Blick_nach_Rechts.html',
#  'Central_District_(Rezvanshahr_County).html',
#  'Gal%C3%A1pagos,_Guadalajara.html',
#  'Campus_of_Texas_A%26M_University.html',
#  'Alexios_Aspietes.html',
#  'Mei_Lanfang.html',
#  'Thalkirchen-Obersendling-Forstenried-F%C3%BCrstenried-Solln.html',
#  'Coalville_Town_railway_station.html',
#  'Gennady_Lesun.html',
#  'Bartrum_Glacier.html',
#  'Victor_S._Mamatey.html',
#  'Gottfried_Keller.html',
#  'Table_Point_Formation.html',
#  'Nobuhiko_Ushiba.html',
#  'Master_of_Space_and_Time.html',
#  'Early_medieval_states_in_Kazakhstan.html',
#  'Eressa_aperiens.html',
#  'Companys,_proc%C3%A9s_a_Catalunya.html',
#  'Myrtle_(sternwheeler).html',
#  'Abanycha_bicolor.html',
#  'Aubrey_Fair.html',
#  'Urban_chicken.html',
#  'Elgin_National_Watch_Company.html',
#  'Goran_Obradovi%C4%87_(footballer,_born_1976).html',
#  'Bluesin%27_Around.html',
#  'Pr%C3%A9liminaires.html',
#  'Antae_temple.html',
#  'Metis_Institute_of_Polytechnic.html',
#  '1953%E2%80%9354_FA_Cup_qualifying_rounds.html',
#  'Sverre_Solberg.html',
#  'John_Reid_(British_Army_officer).html',
#  'List_of_mountains_of_the_Falkland_Islands.html',
#  'Fischli.html',
#  'Aylon_Darwin_Tavella.html',
#  'Sambhaji_Raje_Chhatrapati.html',
#  'Alexander_Rizzoni.html',
#  'Pixley_Township,_Clay_County,_Illinois.html',
#  'Jules_Verne_ATV.html',
#  'Tomohiko_It%C5%8D_(director).html',
#  'Battle_of_Isonzo_(489).html',
#  'Pictogram.html',
#  'Alan_Oakley.html',
#  'Le_Premier_Sexe.html',
#  'Eugamandus_brunneus.html',
#  'Arthur_Norman.html',
#  'Feel_No_Fret.html',
#  'Claire_Danes.html',
#  'Adish_Aggarwala.html',
#  'Egg_coffee.html',
#  'Diplacus_aurantiacus.html',
#  'Sumba%E2%80%93Flores_languages.html',
#  'Justus_Ferdinand_Poggenburg_II.html',
#  'Svendborg_Skibsv%C3%A6rft.html',
#  'Communities_of_Tulu_Nadu.html',
#  'Supermoon.html',
#  'Ron_Harvey_(rugby_union).html',
#  'Olivaceous_flatbill.html',
#  'Javier_Bruses.html',
#  'Mitrella_guerreiroi.html',
#  'Louis_Vivet.html',
#  'Yarkant_County.html',
#  'Mrs._Wilkes%27_Dining_Room.html',
#  'Theonellamide_F.html',
#  'PTPRS.html',
#  'Legge.html',
#  'Constance_D%27Arcy_Mackay.html',
#  'Tom_Buffington.html',
#  'Leuke_Kome.html',
#  'Horace_Pinker.html',
#  'C%27est_la_vie_(Khaled_song).html',
#  'Kelvin_R._Throop.html',
#  'Yemeni_rial.html',
#  'Miss_Guatemala_2008.html',
#  'Merwin_Hodel.html',
#  'A_Beautiful_Valley.html',
#  'H._T._Hackney_Company.html',
#  'Berzeliustinden.html',
#  'John_Nelson_(merchant).html',
#  'Short_Message_service_center.html',
#  'Lebanon_at_the_1980_Winter_Olympics.html',
#  'Streatfeild_family.html',
#  'Kendal_Williams.html',
#  'List_of_women%27s_football_clubs_in_Japan.html',
#  'Tam%C3%A1s_Buday.html',
#  'Jeff_Weise.html',
#  'William_Harper_(South_Carolina).html',
#  '2007%E2%80%9308_Huddersfield_Town_A.F.C._season.html',
#  'Shanghai_Shuffle.html',
#  'Danny_Gray.html',
#  'Platinum_fulminate.html',
#  'Guyana_at_the_2010_Central_American_and_Caribbean_Games.html',
#  'Alpine_skiing_at_the_1994_Winter_Olympics_%E2%80%93_Men%27s_combined.html',
#  'Jeecy-Vea.html',
#  'The_Wire_(JTF-GTMO).html',
#  'Turowo,_Pomeranian_Voivodeship.html',
#  'Mike_Purdy.html',
#  'Hagen_Hauptbahnhof.html',
#  'Patrick_F._Philbin.html',
#  'Ribboned_sweetlips.html',
#  'Endre_Church.html',
#  'Nabil_Baha.html',
#  'Mudramothiram.html',
#  'Schlettau.html',
#  'Ameenapuram.html',
#  'Nathaniel_Merriman.html',
#  '2011_ITU_Duathlon_World_Championships.html',
#  'Mara_Keisling.html',
#  'Ragnar_Gustavsson.html',
#  'William_de_Pembroke.html',
#  'Teskey,_Kyrgyzstan.html',
#  'Mark_Maunder.html',
#  'Wheatland_High_School_(California).html',
#  'Markus_Blutsch.html',
#  'Kristiene_Gong.html',
#  'Punjab_War.html',
#  'Syncretocarpus.html',
#  'Gordon_Bau.html',
#  'Bibliography_of_Niue.html',
#  'Marv_Felderman.html',
#  'Code_page_1023.html',
#  'Discretionary_trust.html',
#  'Cryptographic_primitive.html',
#  'Alex_Kurtzman.html',
#  'William_Samuel_Viner.html',
#  'Nyck_de_Vries.html',
#  'Liga_de_F%C3%BAtbol_Profesional_Boliviano.html',
#  'Scott_McPherson.html',
#  'Kirsten_Klein.html',
#  '2011%E2%80%9312_Western_Collegiate_Hockey_Association_women%27s_ice_hockey_season.html',
#  'List_of_lakes_in_Independence_County,_Arkansas.html',
#  'David_Sands_(psychologist).html',
#  'Beyond_Magnetic.html',
#  'Church_of_the_SubGenius.html',
#  'Vaccinium_padifolium.html',
#  'ZNF644.html',
#  '2005%E2%80%9306_in_Welsh_football.html',
#  'Regina_Pacis_Catholic_Secondary_School.html',
#  'Filip_Pyrochta.html',
#  'Bal%C3%A1zs_Vill%C3%A1m.html',
#  'Gorgopis_subrimosa.html',
#  'Harry_Lynde_Bradley.html',
#  'North_Otago_Astronomical_Society_Observatory.html',
#  'Morgana_King.html',
#  'Don_Parsons_(ice_hockey).html',
#  'Evene.html',
#  'Therese_Maron.html',
#  'Plasnewydd.html',
#  'Belvedere,_London.html',
#  '1958_Wightman_Cup.html',
#  'Bias.html',
#  'Terry_Cox.html',
#  'Heo_Mok.html',
#  'Maple_Jam_Music_Group.html',
#  'Heiko_M%C3%A4rz.html',
#  'Imperial_Venus_(film).html',
#  'Charles_Stuart_(rugby_union).html',
#  'Yarumal.html',
#  'Olive_Dennis.html',
#  'Italy%E2%80%93United_States_relations.html',
#  'Camp_Nelson_Confederate_Cemetery.html',
#  'Treaty_of_Warsaw_(1970).html',
#  'Bill_Widenhouse.html',
#  'Benny_Lee.html',
#  '1898_Colgate_football_team.html',
#  'Caprinia_versicolor.html',
#  'P%C5%82az%C3%B3wka.html',
#  'MoneyHunt.html',
#  'Neville_Hewitt_(American_football).html',
#  'Faces_(Run%E2%80%93D.M.C._song).html',
#  'Dialogue_for_Hungary.html',
#  'Wu_Jin.html',
#  'Kul_Gul.html',
#  'Igor_and_Grichka_Bogdanoff.html',
#  'Tapat%C3%ADo_hot_sauce.html',
#  'Two_House_theology.html',
#  'Tramery.html',
#  'Revolutionary_Vol._1.html',
#  'Gaston_Lane.html',
#  'MobiasBanca.html',
#  'Lectionary_69.html',
#  'Arvind_Gokhale.html',
#  'Thomas_Croci.html',
#  'T%C5%8Dr%C5%8D_nagashi.html',
#  'Medicago_murex.html',
#  'Red-eyed_dove.html',
#  'Jazz_at_the_Plaza_Vol._II.html',
#  'Josef_Mik.html',
#  'AVM_GmbH.html',
#  '2001_Australian_Individual_Speedway_Championship.html',
#  'Mariana_Mazzucato.html',
#  'United_Nations_Security_Council_Resolution_731.html',
#  'Oldfield_Baby_Great_Lakes.html',
#  'Redwater,_Mississippi.html',
#  'Wangerooge-class_tug.html',
#  'Achaea_faber.html',
#  'Ramana,_Pakistan.html',
#  'Charles_Page_(cricketer).html',
#  'Sweeper.html',
#  'Canbelego_County.html',
#  'Wilson_Global_Explorer.html',
#  'Craig_Chester.html',
#  'Derek_Acorah.html',
#  'Wilbraham_%26_Monson_Academy.html',
#  'Mountune_Racing.html',
#  'AB_v_CD.html',
#  'Jack_Goes_Home.html',
#  '2016_Minnesota_Vikings_season.html',
#  'Morning_Glory_(2010_film).html',
#  'Flashmob_(album).html',
#  'I_Marine_Expeditionary_Force.html',
#  'KDDQ.html',
#  'Tim_Spencer_(singer).html',
#  'Suri,_Kerman.html',
#  'Seeking_Gaddafi.html',
#  'Jotedar.html',
#  'Kyokutou_I_Love_You.html',
#  'The_Portal_(community_center).html',
#  'John_C._Freeman_Weather_Museum.html',
#  'Curtiss-Wright_Hangar_(Columbia,_South_Carolina).html',
#  'S%C3%BCderelbe.html',
#  'Mick_Crotty.html',
#  'Juan_Carlos_Pinz%C3%B3n.html',
#  'Now_That%27s_What_I_Call_Music!_55_(U.S._series).html',
#  'Johnny_Morris_(American_football).html',
#  'Lower_Blackburn_Grade_Bridge.html',
#  'Van_Buren,_Ohio.html',
#  'Rules_of_Engagement_(Alexander_novel).html',
#  'The_Wedding_(Sparks_novel).html',
#  'West_Valley,_Washington.html',
#  '2017_Orange_County_Breakers_season.html',
#  'Fureai_kippu.html',
#  'Margo_Reuten.html',
#  'Saladino%27s_Inc.html',
#  'The_Master_Plan_(album).html',
#  'Mark_Baker_(basketball).html',
#  'Zehut.html',
#  'Sol_Eclipse.html',
#  'Para%C3%B1aque_National_High_School,_Don_Galo_Annex.html',
#  '2004_Tuvalu_A-Division.html',
#  'Jonathan_A._Goldstein.html',
#  'Naoise_%C3%93_Muir%C3%AD.html',
#  'F%C3%A9lix_C%C3%A1rdenas.html',
#  '83_(number).html',
#  'SBOA_School_%26_Junior_College.html',
#  'Devil_on_Horseback.html',
#  'Siuniu.html',
#  'Devarampally.html',
#  'SolydXK.html',
#  'Intel_QuickPath_Interconnect.html',
#  'Sierra_Leone_Studies.html',
#  'Harry_Hill_Bandholtz.html',
#  'Bijou,_California.html',
#  'Abdelwahid_Aboud_Mackaye.html',
#  'Equestrian_at_the_1936_Summer_Olympics.html',
#  'Pergamus.html',
#  'Biorock.html',
#  '2016%E2%80%9317_New_Zealand_Football_Championship.html',
#  'Antigonadotropin.html',
#  'Salem-Auburn_Streets_Historic_District.html',
#  'Henrique_da_Silveira.html',
#  'Jane_Wrightson.html',
#  'Gregory_Fortuin.html',
#  'Prisons_in_Bolivia.html',
#  'Ga%C5%A1parci.html',
#  'Paul_Maddrell.html',
#  'Vivian_Prokop.html',
#  'Oued_Tl%C3%A9lat.html',
#  'Paser_Crossword_Stela.html',
#  'Shpolskii_matrix.html',
#  'Bruce_Conte.html',
#  'Old_Mill_Creek,_Illinois.html',
#  'SC_Goldau.html',
#  'Robert_Frederick_Blum.html',
#  'Meydan-e_Jahad_Metro_Station.html',
#  'Sagrai.html',
#  'Falman-County_Acres,_Texas.html',
#  'Sa_Re_Ga_Ma_Pa_Challenge_USA_2008.html',
#  'La_Franja.html',
#  'Estadio_Municipal_Pozoblanco.html',
#  'Unionidae.html',
#  'Corporation_(university).html',
#  '1910_in_literature.html',
#  'Robert_Boehringer.html',
#  'Social_impact_of_YouTube.html',
#  'FC_Khikhani_Khulo.html',
#  'Cobble_Hill,_Brooklyn.html',
#  'The_Lavender_Cowboy.html',
#  'Coup_d%27%C3%A9tat.html',
#  'Tomislav_Erceg.html',
#  'USS_Parris_Island_(AG-72).html',
#  'Meir_Zlotowitz.html',
#  'Awali.html',
#  'Gacharageini.html',
#  'Fortuna_Glacier.html',
#  'Dragnet_(franchise).html',
#  'Winters-Wimberley_House.html',
#  'Ban_On.html',
#  '1915_Montana_football_team.html',
#  'Vijay_Govindarajan.html',
#  'Aiva.html',
#  '2011_Wainwright_Roaming_Buffalo_Classic.html',
#  'Uralochka_Zlatoust.html',
#  'Sybra_preapicemaculata.html',
#  'Papyrus_Oxyrhynchus_56.html',
#  'Promises,_Promises_(Incubus_song).html',
#  'Josh_West.html',
#  'Second_Valley,_South_Australia.html',
#  'Doug_Sahm_and_Band.html',
#  'Hope_7_(album).html',
#  'Mohamed_El-Sayed.html',
#  'Qalat_Kat.html',
#  'Woodward_Dream_Cruise.html',
#  'USS_Goldcrest.html',
#  '2016%E2%80%9317_Little_Rock_Trojans_women%27s_basketball_team.html',
#  'Aniavan.html',
#  'Instrumental.html',
#  'Christopher_Speer.html',
#  'Maniitsoq_structure.html',
#  'Minardi_M185.html',
#  'Millennium_Art_Academy.html',
#  'Australian_Musician_(magazine).html',
#  'Charlton_baronets.html',
#  'Cheddar_Ales.html',
#  'Dewoitine_D.21.html',
#  'List_of_Bellator_MMA_events.html',
#  'Tubular_Bells_II.html',
#  'Touch_FM_(Coventry).html',
#  'Kadamaha.html',
#  'James_L._Hull.html',
#  'Furto_di_sera_bel_colpo_si_spera.html',
#  'Hayes_Township,_Clay_County,_Kansas.html',
#  'Pontefract_by-election,_1941.html',
#  'Meleh_Kabud-e_Sofla.html',
#  'Symeon_Stylites_of_Lesbos.html',
#  'Kellie_Jones.html',
#  'Dominique_Voynet.html',
#  'Mohammad_Reza_Niknahal.html',
#  'Garden-based_learning.html',
#  'Sir_Run_Run_Shaw_Hospital.html',
#  'List_of_Argentine_Primera_Divisi%C3%B3n_transfers_January_2011.html',
#  'Gaetanus_Matthew_Perez.html',
#  'Sudanese_pound.html',
#  'Exploratorium_(film).html',
#  'Foulonia.html',
#  'Reb_Russell.html',
#  'Miltochrista_fuscozonata.html',
#  'Luvvie_Darling.html',
#  'Amborella.html',
#  'List_of_Bratz_episodes.html',
#  'Udi,_Enugu.html',
#  'Canyamars.html',
#  'Kenny_Cordray.html',
#  'Siege_of_Valenciennes_(1793).html',
#  'Santa_Mar%C3%ADa_Yaves%C3%ADa.html',
#  'Baddiewinkle.html',
#  'Chemin_d%27Aylmer.html',
#  'SSR-180,711.html',
#  'David_Solomona.html',
#  'Rally_for_Democracy_and_Progress_(Benin).html',
#  'I_Am_Cold.html',
#  'Sarah_Blakley-Cartwright.html',
#  'Rubber_Biscuit.html',
#  'Heald_Green.html',
#  'Charles_Smith_Wilcox.html',
#  'Swathi_Chinukulu.html',
#  'Noise_(song).html',
#  'Maukala.html',
#  'Hilyard_Robinson.html',
#  'Shellie_Morris.html',
#  'Bob_Bass.html',
#  'Diphilus_(physician).html',
#  'Arun_K._Pati.html',
#  'Agaritine_gamma-glutamyltransferase.html',
#  'Sky_Regional_Airlines.html',
#  'Wilhelm_August_Graah.html',
#  'Avenira.html',
#  'Slade_School_of_Fine_Art.html',
#  'Zane_Radcliffe.html',
#  'Devitt_Insurance.html',
#  'Lincoln_Clarkes.html',
#  'Panhandle%E2%80%93Plains_Historical_Museum.html',
#  'Bahmanabad-e_Olya.html',
#  'Tarsila_do_Amaral.html',
#  'Ioana_Badea.html',
#  'The_Gentleman_Without_a_Residence_(1915_film).html',
#  'Troso_da_Monza.html',
#  'Walter_of_Durham.html',
#  'James_Wilkes_Maurice.html',
#  'Section_20_of_the_Canadian_Charter_of_Rights_and_Freedoms.html',
#  'Ferdinand_Mainzer.html',
#  'Keeled_sideband.html',
#  'Palio_zosterae.html',
#  'Lydia_Villa-Komaroff.html',
#  'Henri_Braqueni%C3%A9.html',
#  'Nickel(II)_hydroxide.html',
#  'Usher_Gahagan.html',
#  'John_V._G._Posey_House.html',
#  'Kfarhata.html',
#  'James_Alexander_Ulio.html',
#  'De_La_Salle_University_%E2%80%93_Dasmari%C3%B1as.html',
#  'When_You_Loved_Me.html',
#  'Flat_roof.html',
#  'Jack_Wong.html',
#  'The_Love-Girl_and_the_Innocent.html',
#  'Manhattan_Murder_Mystery.html',
#  'DiGiorgio_Corporation.html',
#  'Eugenio_Morelli.html',
#  'Kenneth_Thomas_(cricketer).html',
#  'Mar%C3%ADa_Calder%C3%B3n.html',
#  'James_Magee.html',
#  'Bill_Price_(baseball).html',
#  'Mount_Jim_Crow_National_Park.html',
#  'Avengers_Academy.html',
#  'Scrobipalpa_halophila.html',
#  'Swan_neck_deformity.html',
#  'Chhatrasal.html',
#  'Raymond_II,_Count_of_Toulouse.html',
#  'Macroglossum_pseudoluteata.html',
#  'Antibiotic_use_in_livestock.html',
#  'Omaha_Racers.html',
#  'Syngenor.html',
#  'Mecklenburg_Switzerland_and_Lake_Kummerow_Nature_Park.html',
#  'List_of_largest_chemical_producers.html',
#  'X-Cops_(band).html',
#  'Hannover_Indians.html',
#  'Carlos_Martins_(musician).html',
#  'Women%27s_javelin_throw_world_record_progression.html',
#  'Asparuh_Peak.html',
#  'Robert_K._Zukowski.html',
#  'Gorfion.html',
#  'Marson.html',
#  'I%27ve_Heard_That_Song_Before.html',
#  'Jens_Pauli_Skaalum.html',
#  'Chestnut_pie.html',
#  'Vitaly_Bianki.html',
#  'Coronium_(gastropod).html',
#  'Arnold_Freiherr_von_Biegeleben.html',
#  'Acacia_dermatophylla.html',
#  'Lis_L%C3%B8wert.html',
#  'Typhoon_Hester_(1952).html',
#  'Ugo_Okoye.html',
#  '2014%E2%80%9315_Kansas_State_Wildcats_men%27s_basketball_team.html',
#  'Kokan_Colony.html',
#  'Oleg_Novitskiy.html',
#  'Llwyn-Cus.html',
#  'Wilhelm_Wagenfeld_House.html',
#  'Erigeron_canaani.html',
#  'Eternamente_Romanticos.html',
#  'Lecithocera_sextacta.html',
#  'Arthur_Lelyveld.html',
#  'Bonny_River.html',
#  'Charles_Sears.html',
#  'Ingrid_Guimar%C3%A3es.html',
#  'Jonas_Ar%C4%8Dikauskas.html',
#  'Tonga_national_basketball_team.html',
#  'City_of_Mandaluyong_Science_High_School.html',
#  'Oktyabrsky_District,_Russia.html',
#  'Archibald_Gordon_(British_Army_officer).html',
#  'Kusaka_Station.html',
#  'Plze%C5%88_Zoo.html',
#  'WLSR.html',
#  'Friendship,_Wake_County,_North_Carolina.html',
#  'Wolfgang_Lutz.html',
#  'Curridge.html',
#  'Kendalia,_Texas.html',
#  'Celebrity_doll.html',
#  'Venezuelan_referendum,_1957.html',
#  'Australian_hardcore.html',
#  'Lake_County_Examiner.html',
#  'HMS_Robust.html',
#  '985_Innovative_Platforms_for_Key_Disciplines_Project.html',
#  'Hermann_Nuding.html',
#  'Love,_Sax_and_Flashbacks.html',
#  'Kolound.html',
#  'Ordinary,_Virginia.html',
#  'Kanakomyrtus.html',
#  'Bulbophyllum_biflorum.html',
#  'Copamyntis_infusella.html',
#  'Archiepiscopal_Palace,_Rouen.html',
#  'Charged_Records.html',
#  'Cosmopterix_similis.html',
#  'Jyoti_Raju.html',
#  'Apocephalus_borealis.html',
#  'Bernard-Augustin_Conroy.html',
#  'Ready_or_Not_(Young_JV_album).html',
#  'Indhiya_Jananayaga_Katchi.html',
#  'St._Peter%27s_Church,_Tiberias.html',
#  'Parkgate_railway_station.html',
#  'C11orf30.html',
#  'Mr_Freedom_(fashion).html',
#  'Stade_Municipal_de_Djougou.html',
#  'Suwannee_River_Junior_College.html',
#  'Estelle_v._Smith.html',
#  'Arabic_Toilers%27_Movement.html',
#  'Koevtsi,_Gabrovo_Province.html',
#  'Kentucky_Auditor_election,_2011.html',
#  '2013_FIA_WTCC_Race_of_Russia.html',
#  'Taipa_Houses%E2%80%93Museum.html',
#  'Tobi_trousers.html',
#  'Museum_of_John_Paul_II_Collection.html',
#  'Gbiri-Niragu_language.html',
#  'Virajpet_(Vidhan_Sabha_constituency).html',
#  'List_of_people_from_Bangor,_Maine.html',
#  'One_Night_of_Sin.html',
#  'Cabrini%E2%80%93Green,_Chicago.html',
#  'Ek_Dil_Sau_Afsane.html',
#  'Pustiu_River.html',
#  'Majeepura.html',
#  'Tongyi,_Mingin.html',
#  'Zeiraphera.html',
#  'Benidorm_Bastards.html',
#  'Burmese_shrike.html',
#  'Axel_Revold.html',
#  '2009_World_Junior_Ice_Hockey_Championships_rosters.html',
#  'Qatar_at_the_2013_World_Championships_in_Athletics.html',
#  'Nepal_at_the_2008_Summer_Paralympics.html',
#  'Daniel_Cerone.html',
#  'Alan_Sheehan.html',
#  'Work_domain_analysis.html',
#  'Pochyta.html',
#  'Jarom%C3%ADr_%C5%A0imr.html',
#  'Simon%27s_Town_railway_station.html',
#  'Larvicide.html',
#  'Power_transfer_unit.html',
#  'Crab-eating_frog.html',
#  'Percy_William_Bunting.html',
#  'Meanings_of_minor_planet_names:_440,001%E2%80%93450,000.html',
#  'Chief_Justice_of_New_Zealand.html',
#  'KUMT.html',
#  'Vanavara_Airport.html',
#  'Lord_Howe%27s_action,_or_the_Glorious_First_of_June.html',
#  '55th_parallel_south.html',
#  'Aleksandra_Jagie%C5%82o.html',
#  'Curtis_Whitley.html',
#  'Post_(structural).html',
#  'Lake_Lagunitas.html',
#  'Failing_Office_Building.html',
#  'Carley_State_Park.html',
#  'Puerto_Rico_at_the_2013_World_Aquatics_Championships.html',
#  'Eyes_Galaxies.html',
#  'Kistenuten.html',
#  'Children_of_the_Grave.html',
#  'Bagrat_VI_of_Georgia.html',
#  'Pushkar.html',
#  'List_of_Uzbek_films_of_2014.html',
#  'Konstantin_%22Samokovetsa%22_Dimitrov.html',
#  'Cygany,_Masovian_Voivodeship.html',
#  'KMTZ.html',
#  'Football_Foundation.html',
#  'Ministry_of_Development_Planning_and_Statistics.html',
#  'Caney_Creek_(Matagorda_Bay).html',
#  'Solanum_chilliasense.html',
#  'Ballard_Memorial_High_School.html',
#  'Thanks_Again.html',
#  'Dowell_Philip_O%27Reilly.html',
#  'The_Land_of_the_Dead.html',
#  'Yoshinkan.html',
#  'John_Maitland_(Royal_Navy_officer).html',
#  'Social_dualism.html',
#  'Golabkhvaran.html',
#  'Liebig_Peak.html',
#  'Garrett_Lucash.html',
#  'Medical_Unit,_Self-contained,_Transportable.html',
#  '1st_Strategic_Aerospace_Division.html',
#  'Agnolin.html',
#  'Wren,_Alabama.html',
#  'Roselawn,_Indiana.html',
#  'Brograve_Mill.html',
#  'Ashley,_Wisconsin.html',
#  'Blue_SWAT.html',
#  'HMS_Stratagem_(P234).html',
#  'Poor_Richard%27s_Almanack_(TV_series).html',
#  'Pedro_Checa.html',
#  'Martha_Herbert.html',
#  'Goodnight%E2%80%93Loving_Trail.html',
#  'Adolf_Schulte.html',
#  'Danish_Maritime_Safety_Administration.html',
#  'Kiev_Missal.html',
#  'Don_Raye.html',
#  'Precorrin-6A_reductase.html',
#  'Strawberry_foliar_nematode.html',
#  'St._Paul_University_Iloilo.html',
#  'Roger_Brooke.html',
#  'Doumanaba.html',
#  'H._Larue_Renfroe.html',
#  'Giants%27_grave_of_S%27Ena%27e_Thomes.html',
#  'Crepidula_atrasolea.html',
#  'Sahanpur.html',
#  'Ksar_Nalut.html',
#  'Phong_Th%E1%BA%A1nh_%C4%90%C3%B4ng_A.html',
#  'Martinus_Hamconius.html',
#  'Sanford_Wallace.html',
#  'Gratitud.html',
#  'Al-Midan.html',
#  'Iwaki-Ishikawa_Station.html',
#  'Abraham_Stanyan.html',
#  'U.S._Snowboarding_Race_to_the_Cup.html',
#  'Seminemacheilus.html',
#  'British_Academy_Television_Award_for_Best_Comedy_(Programme_or_Series).html',
#  'FC_Bobruisk.html',
#  '2011_UK_Open_Qualifier_4.html',
#  'Monarch_Mountain.html',
#  'Johnny_B._Moore.html',
#  'Ayish_Bayou.html',
#  'Newton_Stone.html',
#  'Treaty_of_Ryswick.html',
#  'Kenneth_van_Kempen.html',
#  'Progressive_refinement.html',
#  'Zoom_Systems.html',
#  'Panchamrutham.html',
#  'Hoghiz.html',
#  'Peltigera_membranacea.html',
#  'Bazemore,_Alabama.html',
#  'Ovum_Recordings.html',
#  'Dick_Johnson_(clarinetist).html',
#  'Urodilatin.html',
#  'Stephen_Unwin_(director).html',
#  'Columbia_Airport_(Ohio).html',
#  'Shibanov.html',
#  'DWTE-TV.html',
#  'Bifidocarpus.html',
#  'Priscus_of_Epirus.html',
#  'Bibiana_Beglau.html',
#  'Ordinary_singularity.html',
#  'Castle_of_Cardona.html',
#  'Emmanuel_Muhammad.html',
#  'Bulbonaricus.html',
#  'Kelvin_Mbilinyi.html',
#  'Emily_(1964_song).html',
#  'Ricard_Card%C3%BAs.html',
#  'Greg_Halsey-Brandt.html',
#  'Kim_Yong-hwa.html',
#  'Queensland_Music_Festival.html',
#  'Clay_Township,_Clark_County,_Missouri.html',
#  'Liberty_Central_School_District.html',
#  'Kamakshyanagar.html',
#  'S%C3%A3o_Sebasti%C3%A3o_do_Alto.html',
#  'Kattukukke.html',
#  'Tischofer_Cave.html',
#  'Rob_Jones_(footballer,_born_1971).html',
#  'Embraer_Unidade_Gavi%C3%A3o_Peixoto_Airport.html',
#  'Barren_vegetation.html',
#  'Burbridge_Creek.html',
#  'Bye!_My_Boy!.html',
#  'Phil_Spence.html',
#  'Ronald_McCaffer.html',
#  'Macy_conferences.html',
#  'Belgium_women%27s_national_field_hockey_team.html',
#  'Dalian_Road_Station.html',
#  'Antonio_de_Zayas_(bishop).html',
#  'Oldham_Metropolitan_Borough_Council_election,_2000.html',
#  'Hideki_Kase.html',
#  'Acceptance_(Heroes).html',
#  'Enamul_Haque_(cricketer,_born_1966).html',
#  'RF_microwave_CAE_CAD.html',
#  'Ego_Dominus_Tuus.html',
#  'High_Efficiency_Image_File_Format.html',
#  'New_York_Women_Composers,_Inc..html',
#  'Newfoundland_general_election,_1848.html',
#  'Lungujja.html',
#  'Smeaton,_East_Lothian.html',
#  'Government_Polytechnic_Nagriya_Mod_Etah.html',
#  'Ma_Sen.html',
#  'Phenacobius_catostomus.html',
#  'Norderbrarup.html',
#  'Octomeria_lithophila.html',
#  'Joint_Committee_for_Traceability_in_Laboratory_Medicine.html',
#  'Yuga_(film).html',
#  'Clay_Research_Award.html',
#  'Kreslyuvtsi.html',
#  '33rd_New_Jersey_Volunteer_Infantry.html',
#  'Steinkjersannan.html',
#  'Carthage,_Cincinnati.html',
#  'Senapati_district.html',
#  'Frost_Township,_Michigan.html',
#  'Bay_of_Concepci%C3%B3n.html',
#  'Chhaparband_(Muslim).html',
#  'Guaricana_National_Park.html',
#  'Challenger_Banque_Nationale_de_Drummondville.html',
#  'Appa_(film).html',
#  'Ben_H._Williams.html',
#  'Hypocysta_angustata.html',
#  'Copenhagen_Skatepark.html',
#  'Saratoga_Automobile_Museum.html',
#  'Madhuri_Desai.html',
#  'Athletics_at_the_1994_Commonwealth_Games_%E2%80%93_Men%27s_pole_vault.html',
#  'Odder.html',
#  'Aldona_Orman.html',
#  'Vancouver_Furious_George.html',
#  'Havnar_R%C3%B3%C3%B0rarfelag.html',
#  'Dextran_1.html',
#  'HD_90156.html',
#  'WFGI-FM.html',
#  'Oculo-respiratory_syndrome.html',
#  'Zhongxing_Guesthouse.html',
#  '1988_State_of_Origin_series.html',
#  'Hemiargyropsis_frontalis.html',
#  'The_Audacity_to_Podcast.html',
#  'List_of_Polish_consorts.html',
#  'Third_Saturday_in_October.html',
#  'Antipater_of_Thessalonica.html',
#  'Santa_Maria_Imbaro.html',
#  'Brownfield_(software_development).html',
#  'George_Joseph_Trapp.html',
#  'Russell_Road_(Ontario).html',
#  'Maneswar_Brahma.html',
#  'Robin_Brooke.html',
#  '100_Greatest_Romanians.html',
#  'Cristian_Berdeja.html',
#  'King_Parker_House.html',
#  'Al-Nurayn_Mosque.html',
#  'John_Shaw_Rennie.html',
#  'Sobolewo,_Wysokie_Mazowieckie_County.html',
#  'Meneng_Constituency.html',
#  'List_of_Spaghetti_Western_films.html',
#  'Paul_Kenny_(politician).html',
#  'Luca_Luciano.html',
#  'Cannabis_in_Spain.html',
#  'VSX2.html',
#  'Varsity_College.html',
#  'Fahy,_County_Mayo.html',
#  'Keegan_Pereira_(footballer).html',
#  'Eudonia_notozeucta.html',
#  'Pirama.html',
#  'Shinpei_Matsushita.html',
#  'Boardman_Township,_Mahoning_County,_Ohio.html',
#  'Anton_von_Troeltsch.html',
#  'Vang_stone.html',
#  'Heinz_Inniger.html',
#  'Marion_Rockefeller_Weber.html',
#  'Abdulla_Majid_Al_Naimi.html',
#  'The_Future_(film).html',
#  'Fusinus_carvalhoriosi.html',
#  'List_of_Nymphaeales_of_Montana.html',
#  'Weiser_River.html',
#  'Elzear_Torreggiani.html',
#  'Scarlet_wrasse.html',
#  'Svinjare.html',
#  'G.O.Y.A._(Gunz_Or_Yay_Available).html',
#  'Switzerland_at_the_1992_Winter_Olympics.html',
#  'Chef_Wan.html',
#  'Viva_Villa!.html',
#  'Jon_Mullich.html',
#  'Clear_Creek_Township,_Cooper_County,_Missouri.html',
#  'A_Sport_and_a_Pastime.html',
#  'The_Right_Kinda_Lover.html',
#  'Plains,_Kansas.html',
#  'Baadj.html',
#  'George_Ellicott.html',
#  'Cortile_del_Belvedere.html',
#  'Mick_Kelly_(Australian_footballer).html',
#  'Somarasampettai.html',
#  'David_Jesson.html',
#  '%C5%8Cnog%C5%8D_Station.html',
#  'Nuno_Leal_Maia.html',
#  'Battle_of_Wattignies.html',
#  'Saravan,_Gilan.html',
#  'Colchester_Village_Historic_District.html',
#  'Watsonville_Junction,_California.html',
#  'Hayateumi_Hidehito.html',
#  'Oliver_Twist_(1912_American_film).html',
#  'Omar_Onsi.html',
#  'Utiel-Requena.html',
#  'Volume_One_(The_West_Coast_Pop_Art_Experimental_Band_album).html',
#  'Pozna%C5%84_Wola_railway_station.html',
#  'ISMACryp.html',
#  'Mirisah.html',
#  'USS_Impeccable_(AM-320).html',
#  'Bengt_Forsberg.html',
#  'Irihirose_Station.html',
#  'A_Month_of_Sundays_(miniseries).html',
#  'Teiji_Ito.html',
#  'Robert_E._Lee_(FCC).html',
#  'Giardini_Margherita.html',
#  'Upper_Beaches.html',
#  'Minister_of_Foreign_Affairs_(Egypt).html',
#  'Italian_submarine_Comandante_Fa%C3%A0_di_Bruno.html',
#  'Christine_Gardner.html',
#  'Durham_Women%27s_F.C..html',
#  'USS_Rose_Mary_(SP-1216).html',
#  'Shoreyjeh-ye_Do.html',
#  '%C3%89cole_des_Mines_de_Douai.html',
#  'Luciano_Mercante.html',
#  'Jeff_Boyd.html',
#  'Abbeville_Sluggers.html',
#  'East_Down_(Northern_Ireland_Parliament_constituency).html',
#  'Russian_Cultural_Centre_(Lviv).html',
#  'Morten_Rutkj%C3%A6r.html',
#  'Du%C5%A1anovo.html',
#  'Bowie_Race_Track.html',
#  'Gemma_Doyle_(politician).html',
#  'Thornton-le-Beans.html',
#  'Tommy_Hunter_(baseball).html',
#  'S%C3%B8rli.html',
#  'Frithjof_Schmidt.html',
#  'ARA_Garibaldi.html',
#  'How_Can_We_Hang_On_to_a_Dream%3F.html',
#  'Schwobsheim.html',
#  'Arrondissements_of_the_Yvelines_department.html',
#  'L._Fry.html',
#  'Hepatitis_B_virus.html',
#  'Jordan_Steel.html',
#  'Central_Luzon.html',
#  'Jack_Graham_(pastor).html',
#  'Sentences_(composition).html',
#  'Tropical_sprue.html',
#  'Elisa_von_der_Recke.html',
#  'Neurotica.html',
#  'Roxbury_Presbyterian_Church.html',
#  'Moosavi_Peace_Formula.html',
#  'Acrolophus_simulatus.html',
#  'Dennis_Chapman.html',
#  'Uruguayan_constitutional_referendum,_2014.html',
#  'Peter_Collingwood.html',
#  'List_of_molecular_graphics_systems.html',
#  'MOUSE_DHI.html',
#  'Hexachaeta_colombiana.html',
#  'Sot%C4%81panna.html',
#  '2015%E2%80%9316_Washington_Huskies_men%27s_basketball_team.html',
#  'Oligocentris_deciusalis.html',
#  '2008_Fed_Cup_World_Group_II.html',
#  'Camp_Liberty_killings.html',
#  'Hemet_Public_Library.html',
#  'Lin_Chia-yu.html',
#  'Omiodes_iridias.html',
#  'Shigeo_Kurata.html',
#  'Arthur_L._Aidala.html',
#  'Clocking_Out_Is_for_Suckers.html',
#  'List_of_gold_medalists_at_2006_South_Asian_Games.html',
#  'Gew%C3%A4chshaus_f%C3%BCr_tropische_Nutzpflanzen.html',
#  'The_Purpose_Driven_Church.html',
#  'Brendan_Foster.html',
#  'I%27m_Walking_Behind_You.html',
#  'Glinka_(crater).html',
#  'Larry_Brooks.html',
#  'Socket_423.html',
#  'Double_Wing_Attack.html',
#  'Arkansas_Highway_178.html',
#  'Taylour_Paige.html',
#  'Fraser_Lake_Airport.html',
#  'Potheri_village,_Kanchipuram.html',
#  'Pedro_Machuca.html',
#  'Roll%27s_partridge.html',
#  'Nejat_Alp.html',
#  'Checkerspot_(magazine).html',
#  'Functoid.html',
#  'Manitoba_general_election,_1896.html',
#  'Roman_Catholic_Diocese_of_Cervia.html',
#  'Lopez_v._Davis.html',
#  'Coenaculum_secundum.html',
#  'Football_at_the_National_Games_of_China.html',
#  'Vojin_%C4%86etkovi%C4%87.html',
#  'Sibling_Revelry.html',
#  'Isaac_Gr%C3%BCnewald.html',
#  'Waldoboro_(CDP),_Maine.html',
#  'Cecyl%C3%B3wka-Brz%C3%B3zka.html',
#  'List_of_birds_of_Malta.html',
#  '2009_English_cricket_season.html',
#  'Banovina_of_Croatia.html',
#  'Dakar_2:_The_World%27s_Ultimate_Rally.html',
#  'Anthony_Marten.html',
#  'Arcadio_Gonz%C3%A1lez.html',
#  'Boogie_Bunnies.html',
#  'Roque_P%C3%A9rez_Partido.html',
#  'Andrei_Gamalyan.html',
#  'Mykines,_Greece.html',
#  'Dresden-Plauen_railway_station.html',
#  'Kailas_Pal.html',
#  'Bad_Luck_(Social_Distortion_song).html',
#  'I,_Q_(book_series).html',
#  'Julien_Boisselier.html',
#  'Turkish_Men%27s_Volleyball_Championship.html',
#  'Joint_Social_Welfare_Institute.html',
#  'The_Summer_King.html',
#  'Burnin%27_Sneakers.html',
#  'Chapel_of_Mercy,_Monaco-Ville.html',
#  'Jazz_in_Turkey.html',
#  'Burnley_Borough_Council_election,_2011.html',
#  'National_Register_of_Historic_Places_listings_in_Allen_Parish,_Louisiana.html',
#  'Luiz_Henrique_Santos.html',
#  'Yasid.html',
#  '2001_NCAA_Division_I_Field_Hockey_Championship.html',
#  'Ctenodes_zonata.html',
#  'EDP_Sarichioi_Wind_Farm.html',
#  'Carte_Imagine%27R.html',
#  'Holly_Golightly_(comics).html',
#  'Johann_Christoph_Hoffbauer.html',
#  'Matthew_Liptak.html',
#  'Programa_Mejorando_tu_Autoestima.html',
#  'Philaeus.html',
#  'Kate_Harwood.html',
#  'Baltic_Peak.html',
#  'Westchester,_Los_Angeles.html',
#  'Laredo_Colombia_Solidarity_Port_of_Entry.html',
#  '104th_Logistic_Support_Brigade_(United_Kingdom).html',
#  'Pichoy_Airfield.html',
#  'Wreck_Island_Natural_Area_Preserve.html',
#  'Desmiphora_bijuba.html',
#  'Webb_Dock_railway_line.html',
#  'Helena_Nyblom.html',
#  'Hall_of_Mental_Cultivation.html',
#  'John_Whewell.html',
#  '2014%E2%80%9315_Albanian_Third_Division.html',
#  'Gulliver_Mickey.html',
#  'Henry_Horace_Williams.html',
#  'Hebden_Bridge_Picture_House.html',
#  'Marie-Jos%C3%A8phe_Jude.html',
#  'Circus_Avenue.html',
#  'Kettu_Kalyanam.html',
#  'Union_United_Church.html',
#  'Bill_Overstreet.html',
#  'Urs_Burkart.html',
#  'The_K_of_D.html',
#  'Gandigwad.html',
#  'Kentucky_Theater.html',
#  'USS_General_Putnam_(1857).html',
#  'George_Jones_(bishop).html',
#  'United_Nations_Security_Council_Resolution_1923.html',
#  'The_Hackensaw_Boys.html',
#  'Harry_Sacksioni.html',
#  'David_Beasley.html',
#  'Piracy_on_Falcon_Lake.html',
#  'Mammoth_Unified_School_District.html',
#  'Eggerberg_railway_station.html',
#  'Tillandsia_intermedia.html',
#  'Town_Yetholm.html',
#  'S%27portable_Scoreboards.html',
#  'Sparganothis_saracana.html',
#  'Smilax_laurifolia.html',
#  'Taylor_Williamson.html',
#  'Epropetes_metallica.html',
#  'Melanolagus_bericoides.html',
#  'BBCH-scale_(rice).html',
#  'La_Roca_de_la_Sierra.html',
#  'Russian_Party_in_Estonia.html',
#  'Henry_Louis_Larsen.html',
#  'Torovirinae.html',
#  'Moses_Hardy.html',
#  '1896_Indiana_Hoosiers_football_team.html',
#  'Els_Dottermans.html',
#  'Epichorista.html',
#  'Ownership_of_Rangers_F.C..html',
#  'Clinton_Engineer_Works.html',
#  'It%27s_Just_My_Funny_Way_of_Laughin%27.html',
#  'The_Showdown_Effect.html',
#  'My_Life_(Billy_Joel_song).html',
#  'Ramo_Stott.html',
#  'Geomancer_(comics).html',
#  'Enrique_Morales.html',
#  'Linowiec,_Kuyavian-Pomeranian_Voivodeship.html',
#  'Triptolemus_Evrychou.html',
#  'Claudia_Neidig.html',
#  'Keshav_Ginde.html',
#  'Cyclohexane_conformation.html',
#  'Dean_Kukan.html',
#  'List_of_Carboniferous_tetrapods.html',
#  'Sol_Orwell.html',
#  'Lucius_Allen_(politician).html',
#  'Elio_Calderini.html',
#  'Demographics_of_American_Samoa.html',
#  'Middle_Park,_Victoria.html',
#  'Peringiella_denticulata.html',
#  'Y%C3%AAn_B%C3%A1i.html',
#  'Young_Finnish_Party.html',
#  'Rudy:_The_Rudy_Giuliani_Story.html',
#  'Dysgonia_pudica.html',
#  'Klaus_Gerwien.html',
#  'Lee_Henderson_Watkins.html',
#  '%C3%89taule.html',
#  'Sabari.html',
#  'Timothy_Wanyonyi_Wetangula.html',
#  'Ivo_Siromahov.html',
#  'John_Jephson.html',
#  'Land_%26_Water_Australia.html',
#  'Shabbir_Kumar.html',
#  'Sylvia_Moss.html',
#  'West_Park_Bridge.html',
#  'Imperial_amazon.html',
#  '16th_Virginia_Infantry.html',
#  'North_Coast_(RTA_Rapid_Transit_station).html',
#  'Alex_McEachern.html',
#  'Kate_Quarrie.html',
#  'Cyclone_Gamede.html',
#  'William_McDonald_(Australian_politician).html']

# %%
len(os.listdir("wiki"))
# Out:
# 999

# %%
with open("wiki/Campus_of_Texas_A%26M_University.html") as f:
    print(f.read())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Campus of Texas A&amp;M University - Wikipedia</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# <script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Campus_of_Texas_A\u0026M_University","wgTitle":"Campus of Texas A\u0026M University","wgCurRevisionId":767577617,"wgRevisionId":767577617,"wgArticleId":11246998,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["All articles with dead external links","Articles with dead external links from September 2016","Articles with dead external links from January 2017","Articles with permanently dead external links","Articles with dead external links from April 2009","Articles with dead external links from June 2008","Pages with login required references or sources","Articles with dead external links from September 2010","Articles with dead external links from November 2016","Webarchive template wayback links","Use mdy dates from February 2013","Articles to be split from November 2013","All articles to be split","Pages with Split section templates needing conversion of 2 to discuss","Coordinates on Wikidata","Texas A\u0026M University","College Station, Texas","University and college campuses in Texas","Buildings and structures in Brazos County, Texas"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"Campus_of_Texas_A\u0026M_University","wgRelevantArticleId":11246998,"wgRequestId":"WLfHogpAEKYAAGVTmJUAAALC","wgIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{}},"wgStableRevisionId":null,"wgWikiEditorEnabledModules":{"toolbar":true,"dialogs":true,"preview":false,"publish":false},"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsShouldSendModuleToUser":false,"wgPopupsConflictsWithNavPopupGadget":false,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","usePageImages":true,"usePageDescriptions":true},"wgPreferredVariant":"en","wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":true},"wgRelatedArticles":null,"wgRelatedArticlesBetaFeatureEnabled":false,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgCategoryTreePageCategoryOptions":"{\"mode\":0,\"hideprefix\":20,\"showcount\":true,\"namespaces\":false}","wgCoordinates":{"lat":30.62663,"lon":-96.34105},"wgWikibaseItemId":"Q5028713","wgCentralAuthMobileDomain":false,"wgVisualEditorToolbarScrollOffset":0,"wgEditSubmitButtonLabelPublish":false});mw.loader.state({"ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","user":"ready","user.options":"loading","user.tokens":"loading","ext.cite.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.sectionAnchor":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready"});mw.loader.implement("user.options@0j3lz3q",function($,jQuery,require,module){mw.user.options.set({"variant":"en"});});mw.loader.implement("user.tokens@1dqfd7l",function ( $, jQuery, require, module ) {
# mw.user.tokens.set({"editToken":"+\\","patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});/*@nomin*/;
#
# });mw.loader.load(["ext.cite.a11y","mediawiki.toc","mediawiki.action.view.postEdit","site","mediawiki.page.startup","mediawiki.user","mediawiki.hidpi","mediawiki.page.ready","mediawiki.legacy.wikibits","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.gadget.featured-articles-links","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging.subscriber","ext.wikimediaEvents","ext.navigationTiming","ext.uls.eventlogger","ext.uls.init","ext.uls.interface","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"]);});</script>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.sectionAnchor%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>
# <script async="" src="/w/load.php?debug=false&amp;lang=en&amp;modules=startup&amp;only=scripts&amp;skin=vector"></script>
# <meta name="ResourceLoaderDynamicStyles" content=""/>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>
# <meta name="generator" content="MediaWiki 1.29.0-wmf.13"/>
# <meta name="referrer" content="origin-when-cross-origin"/>
# <meta property="og:image" content="https://upload.wikimedia.org/wikipedia/commons/a/a9/Academicplaza.JPG"/>
# <link rel="alternate" href="android-app://org.wikipedia/http/en.m.wikipedia.org/wiki/Campus_of_Texas_A%26M_University"/>
# <link rel="alternate" type="application/x-wiki" title="Edit this page" href="/w/index.php?title=Campus_of_Texas_A%26M_University&amp;action=edit"/>
# <link rel="edit" title="Edit this page" href="/w/index.php?title=Campus_of_Texas_A%26M_University&amp;action=edit"/>
# <link rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png"/>
# <link rel="shortcut icon" href="/static/favicon/wikipedia.ico"/>
# <link rel="search" type="application/opensearchdescription+xml" href="/w/opensearch_desc.php" title="Wikipedia (en)"/>
# <link rel="EditURI" type="application/rsd+xml" href="//en.wikipedia.org/w/api.php?action=rsd"/>
# <link rel="copyright" href="//creativecommons.org/licenses/by-sa/3.0/"/>
# <link rel="canonical" href="https://en.wikipedia.org/wiki/Campus_of_Texas_A%26M_University"/>
# <link rel="dns-prefetch" href="//login.wikimedia.org"/>
# <link rel="dns-prefetch" href="//meta.wikimedia.org" />
# </head>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-Campus_of_Texas_A_M_University rootpage-Campus_of_Texas_A_M_University skin-vector action-view">		<div id="mw-page-base" class="noprint"></div>
# 		<div id="mw-head-base" class="noprint"></div>
# 		<div id="content" class="mw-body" role="main">
# 			<a id="top"></a>
#
# 							<div id="siteNotice"><!-- CentralNotice --></div>
# 						<div class="mw-indicators">
# </div>
# 			<h1 id="firstHeading" class="firstHeading" lang="en">Campus of Texas A&amp;M University</h1>
# 									<div id="bodyContent" class="mw-body-content">
# 									<div id="siteSub">From Wikipedia, the free encyclopedia</div>
# 								<div id="contentSub"></div>
# 												<div id="jump-to-nav" class="mw-jump">
# 					Jump to:					<a href="#mw-head">navigation</a>, 					<a href="#p-search">search</a>
# 				</div>
# 				<div id="mw-content-text" lang="en" dir="ltr" class="mw-content-ltr"><div class="thumb tright">
# <div class="thumbinner" style="width:302px;"><a href="/wiki/File:Academicplaza.JPG" class="image"><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/a9/Academicplaza.JPG/300px-Academicplaza.JPG" width="300" height="225" class="thumbimage" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/a9/Academicplaza.JPG/450px-Academicplaza.JPG 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/a9/Academicplaza.JPG/600px-Academicplaza.JPG 2x" data-file-width="902" data-file-height="676" /></a>
# <div class="thumbcaption">
# <div class="magnify"><a href="/wiki/File:Academicplaza.JPG" class="internal" title="Enlarge"></a></div>
# Academic Plaza</div>
# </div>
# </div>
# <p>The <b>campus of Texas A&amp;M University</b>, also known as <b>Aggieland</b>, is situated in <a href="/wiki/College_Station,_Texas" title="College Station, Texas">College Station, Texas</a>, United States. <a href="/wiki/Texas_A%26M" class="mw-redirect" title="Texas A&amp;M">Texas A&amp;M</a> is centrally located within 200 miles (320&#160;km) of three of the 10 largest cities in the United States and 75% of the Texas and <a href="/wiki/Louisiana" title="Louisiana">Louisiana</a> populations. Aggieland's major roadway is <a href="/wiki/Texas_State_Highway_6" title="Texas State Highway 6">State Highway 6</a>, and several smaller state highways and <a href="/wiki/Farm_to_Market_Road" class="mw-redirect" title="Farm to Market Road">Farm to Market Roads</a> connect the area to larger highways such as <a href="/wiki/Interstate_45" title="Interstate 45">Interstate 45</a>.<sup id="cite_ref-bcschamber_1-0" class="reference"><a href="#cite_note-bcschamber-1">[1]</a></sup></p>
# <p>The campus is <a href="/wiki/Bisection" title="Bisection">bisected</a> by a set of railroad tracks primarily operated by <a href="/wiki/Union_Pacific_Railroad" title="Union Pacific Railroad">Union Pacific Railroad</a>.<sup id="cite_ref-lukejackson_2-0" class="reference"><a href="#cite_note-lukejackson-2">[2]</a></sup> The area east of the railroad tracks is known as "Main Campus"<sup id="cite_ref-campusname_3-0" class="reference"><a href="#cite_note-campusname-3">[3]</a></sup> and includes many of the academic buildings, the Memorial Student Center, <a href="/wiki/Kyle_Field" title="Kyle Field">Kyle Field</a>, and the student dormitories. The portion of the campus west of the railroad tracks is known as "West Campus" and includes most of the other sports facilities, the business school, agricultural programs, the veterinary college, the George Bush Presidential Library and the medical school. The area of West Campus along Kimbrough Boulevard is known as "Research Park" and includes many research facilities.<sup id="cite_ref-vision2020campus_4-0" class="reference"><a href="#cite_note-vision2020campus-4">[4]</a></sup><sup id="cite_ref-campusmap_5-0" class="reference"><a href="#cite_note-campusmap-5">[5]</a></sup></p>
# <p></p>
# <div id="toc" class="toc">
# <div id="toctitle">
# <h2>Contents</h2>
# </div>
# <ul>
# <li class="toclevel-1 tocsection-1"><a href="#History"><span class="tocnumber">1</span> <span class="toctext">History</span></a>
# <ul>
# <li class="toclevel-2 tocsection-2"><a href="#Establishment"><span class="tocnumber">1.1</span> <span class="toctext">Establishment</span></a></li>
# <li class="toclevel-2 tocsection-3"><a href="#Sul_Ross_era"><span class="tocnumber">1.2</span> <span class="toctext">Sul Ross era</span></a></li>
# <li class="toclevel-2 tocsection-4"><a href="#Early_20th_century"><span class="tocnumber">1.3</span> <span class="toctext">Early 20th century</span></a></li>
# <li class="toclevel-2 tocsection-5"><a href="#World_War_II"><span class="tocnumber">1.4</span> <span class="toctext">World War II</span></a></li>
# <li class="toclevel-2 tocsection-6"><a href="#Late_20th_century"><span class="tocnumber">1.5</span> <span class="toctext">Late 20th century</span></a></li>
# <li class="toclevel-2 tocsection-7"><a href="#The_2004_Campus_Master_Plan"><span class="tocnumber">1.6</span> <span class="toctext">The 2004 Campus Master Plan</span></a></li>
# <li class="toclevel-2 tocsection-8"><a href="#Current_Status"><span class="tocnumber">1.7</span> <span class="toctext">Current Status</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-9"><a href="#Areas"><span class="tocnumber">2</span> <span class="toctext">Areas</span></a>
# <ul>
# <li class="toclevel-2 tocsection-10"><a href="#Main_Campus"><span class="tocnumber">2.1</span> <span class="toctext">Main Campus</span></a></li>
# <li class="toclevel-2 tocsection-11"><a href="#East_Campus"><span class="tocnumber">2.2</span> <span class="toctext">East Campus</span></a></li>
# <li class="toclevel-2 tocsection-12"><a href="#West_Campus"><span class="tocnumber">2.3</span> <span class="toctext">West Campus</span></a></li>
# <li class="toclevel-2 tocsection-13"><a href="#Riverside_Campus"><span class="tocnumber">2.4</span> <span class="toctext">Riverside Campus</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-14"><a href="#Residential_life"><span class="tocnumber">3</span> <span class="toctext">Residential life</span></a></li>
# <li class="toclevel-1 tocsection-15"><a href="#Notable_buildings"><span class="tocnumber">4</span> <span class="toctext">Notable buildings</span></a>
# <ul>
# <li class="toclevel-2 tocsection-16"><a href="#Academic_Building"><span class="tocnumber">4.1</span> <span class="toctext">Academic Building</span></a></li>
# <li class="toclevel-2 tocsection-17"><a href="#Albritton_Bell_Tower"><span class="tocnumber">4.2</span> <span class="toctext">Albritton Bell Tower</span></a></li>
# <li class="toclevel-2 tocsection-18"><a href="#Eller_O.26M_Building"><span class="tocnumber">4.3</span> <span class="toctext">Eller O&amp;M Building</span></a></li>
# <li class="toclevel-2 tocsection-19"><a href="#E.V._Adams_Band_Hall"><span class="tocnumber">4.4</span> <span class="toctext">E.V. Adams Band Hall</span></a></li>
# <li class="toclevel-2 tocsection-20"><a href="#The_George_Bush_Presidential_Library_and_Museum"><span class="tocnumber">4.5</span> <span class="toctext">The George Bush Presidential Library and Museum</span></a></li>
# <li class="toclevel-2 tocsection-21"><a href="#Jack_K._Williams_Administration_Building"><span class="tocnumber">4.6</span> <span class="toctext">Jack K. Williams Administration Building</span></a></li>
# <li class="toclevel-2 tocsection-22"><a href="#Kyle_Field"><span class="tocnumber">4.7</span> <span class="toctext">Kyle Field</span></a></li>
# <li class="toclevel-2 tocsection-23"><a href="#Memorial_Student_Center"><span class="tocnumber">4.8</span> <span class="toctext">Memorial Student Center</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-24"><a href="#Transportation"><span class="tocnumber">5</span> <span class="toctext">Transportation</span></a></li>
# <li class="toclevel-1 tocsection-25"><a href="#Other_facilities"><span class="tocnumber">6</span> <span class="toctext">Other facilities</span></a>
# <ul>
# <li class="toclevel-2 tocsection-26"><a href="#Texas_A.26M_Health_Science_Center"><span class="tocnumber">6.1</span> <span class="toctext">Texas A&amp;M Health Science Center</span></a></li>
# <li class="toclevel-2 tocsection-27"><a href="#Texas_A.26M_School_of_Law"><span class="tocnumber">6.2</span> <span class="toctext">Texas A&amp;M School of Law</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-28"><a href="#Footnotes"><span class="tocnumber">7</span> <span class="toctext">Footnotes</span></a></li>
# <li class="toclevel-1 tocsection-29"><a href="#References"><span class="tocnumber">8</span> <span class="toctext">References</span></a></li>
# <li class="toclevel-1 tocsection-30"><a href="#External_links"><span class="tocnumber">9</span> <span class="toctext">External links</span></a></li>
# </ul>
# </div>
# <p></p>
# <h2><span class="mw-headline" id="History">History</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Campus_of_Texas_A%26M_University&amp;action=edit&amp;section=1" title="Edit section: History">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <div role="note" class="hatnote">Main article: <a href="/wiki/History_of_Texas_A%26M_University" title="History of Texas A&amp;M University">History of Texas A&amp;M University</a></div>
# <h3><span class="mw-headline" id="Establishment">Establishment</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Campus_of_Texas_A%26M_University&amp;action=edit&amp;section=2" title="Edit section: Establishment">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <div class="thumb tright">
# <div class="thumbinner" style="width:222px;"><a href="/wiki/File:Texas_A%26M_1883_campus.jpg" class="image"><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/2a/Texas_A%26M_1883_campus.jpg/220px-Texas_A%26M_1883_campus.jpg" width="220" height="179" class="thumbimage" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/2a/Texas_A%26M_1883_campus.jpg/330px-Texas_A%26M_1883_campus.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/2a/Texas_A%26M_1883_campus.jpg/440px-Texas_A%26M_1883_campus.jpg 2x" data-file-width="540" data-file-height="440" /></a>
# <div class="thumbcaption">
# <div class="magnify"><a href="/wiki/File:Texas_A%26M_1883_campus.jpg" class="internal" title="Enlarge"></a></div>
# Texas A&amp;M in 1883</div>
# </div>
# </div>
# <p>The Agricultural and Mechanical College of Texas, later known as Texas A&amp;M University was established by the <a href="/wiki/Texas_State_Legislature" class="mw-redirect" title="Texas State Legislature">Texas State Legislature</a> on April 17, 1871 as the state's first public institution of higher education. The legislature provided $75,000 for the construction of buildings at the new school. A committee tasked with finding a home for the new college chose <a href="/wiki/Brazos_County,_Texas" title="Brazos County, Texas">Brazos County</a>, which agreed to donate 2,416 acres (10&#160;km<sup>2</sup>) of land.<sup id="cite_ref-handbook_6-0" class="reference"><a href="#cite_note-handbook-6">[6]</a></sup></p>
# <p>The college officially opened on October 4, 1876, with six professors. Livestock roamed freely but cautiously, and the area served as a meeting point for the <a href="/wiki/Great_Western_Cattle_Trail" title="Great Western Cattle Trail">Great Western Cattle Trail</a>.<sup id="cite_ref-dethloff1617_7-0" class="reference"><a href="#cite_note-dethloff1617-7">[7]</a></sup> The first building to be placed on campus was known as Old Main. "A stately, semi-classic building four stories in height", Old Main housed all the activities of the college for the first ten years of the school's existence. In the following three decades, it played a prominent part in A&amp;M activities and housed the offices of the school's presidents. The building caught fire in the early hours of May 27, 1912, and was unable to be saved.<sup id="cite_ref-oldmain_8-0" class="reference"><a href="#cite_note-oldmain-8">[8]</a></sup> <sup id="cite_ref-gaithright_9-0" class="reference"><a href="#cite_note-gaithright-9">[9]</a></sup></p>
# <h3><span class="mw-headline" id="Sul_Ross_era">Sul Ross era</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Campus_of_Texas_A%26M_University&amp;action=edit&amp;section=3" title="Edit section: Sul Ross era">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <div class="thumb tleft">
# <div class="thumbinner" style="width:222px;"><a href="/wiki/File:Century_Tree.jpg" class="image"><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/34/Century_Tree.jpg/220px-Century_Tree.jpg" width="220" height="147" class="thumbimage" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/34/Century_Tree.jpg/330px-Century_Tree.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/34/Century_Tree.jpg/440px-Century_Tree.jpg 2x" data-file-width="3456" data-file-height="2304" /></a>
# <div class="thumbcaption">
# <div class="magnify"><a href="/wiki/File:Century_Tree.jpg" class="internal" title="Enlarge"></a></div>
# The Century Tree, planted in 1898</div>
# </div>
# </div>
# <p>Many people credit Texas A&amp;M president <a href="/wiki/Lawrence_Sullivan_Ross" title="Lawrence Sullivan Ross">Lawrence Sullivan Ross</a>, known affectionately to students as "Sully", with saving the school from closure and transforming it into a respected military institution.<sup id="cite_ref-ferrell_10-0" class="reference"><a href="#cite_note-ferrell-10">[10]</a></sup> Ross, the immediate past <a href="/wiki/Governor_of_Texas" title="Governor of Texas">governor of Texas</a>, had been a well-respected <a href="/wiki/Confederate_States_of_America" title="Confederate States of America">Confederate</a> soldier along with being a <a href="/wiki/Baylor_University" title="Baylor University">Baylor</a> graduate and he enjoyed a good reputation among state residents.<sup id="cite_ref-handbook_6-1" class="reference"><a href="#cite_note-handbook-6">[6]</a></sup> When Ross arrived at the school in February 1891, he found that there was no running water, the school was suffering a housing shortage, the faculty was disgruntled, and many of the students ran wild.<sup id="cite_ref-ferrell_10-1" class="reference"><a href="#cite_note-ferrell-10">[10]</a></sup> Ross promptly began instituting improvements. When students returned for the 1891–1892 school year, they found a new three–story, 41&#160;room dormitory (named Ross Hall), the beginning of construction on a new home for the president, and a new building to house the machine and blacksmith shops. Even with the addition of a new dormitory, space was still at a premium. Some cadets were forced to live on the fourth floor of the main building.<sup id="cite_ref-11" class="reference"><a href="#cite_note-11">[11]</a></sup></p>
# <p>Enrollment continued to rise, so much so that by the end of his tenure Ross requested that parents first communicate with his office before sending their sons to the school.<sup id="cite_ref-12" class="reference"><a href="#cite_note-12">[12]</a></sup> The increase in students necessitated an improvement in facilities, and from fall 1891 until September 1898 the college spent over $97,000 on improvements and new buildings. This included construction of an infirmary, which included the first indoor toilets on campus, a new artesian well, a natatorium, four new faculty residences, an electric light plant, an ice works, a laundry, a cold storage room, a slaughterhouse, a gymnasium, a warehouse, and an artillery shed.<sup id="cite_ref-13" class="reference"><a href="#cite_note-13">[13]</a></sup></p>
# <p>The last major campus construction overseen by Ross was the development of the Mess Hall. Designed by architectural firm Glover and Allen and opened in 1897, the Mess Hall could originally seat 500 students. Its front porches were later enclosed to double the seating capacity, making the Mess Hall the largest dining hall in Texas. An accidental kitchen fire on the morning of November 11, 1911, destroyed the building. Its replacement, Sbisa Dining Hall, remains one of the primary dining centers on campus.<sup id="cite_ref-oldmesshall_14-0" class="reference"><a href="#cite_note-oldmesshall-14">[14]</a></sup></p>
# <p>During this time one of the more recognizable features of the Texas A&amp;M landscape, the Century Oak Tree, was planted. The massive <a href="/wiki/Oak_tree" class="mw-redirect" title="Oak tree">oak tree</a>, located in Academic Plaza, would become a favored place for students to propose marriage.<sup id="cite_ref-orton_15-0" class="reference"><a href="#cite_note-orton-15">[15]</a></sup></p>
# <h3><span class="mw-headline" id="Early_20th_century">Early 20th century</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Campus_of_Texas_A%26M_University&amp;action=edit&amp;section=4" title="Edit section: Early 20th century">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>The focal point of campus for much of the early 20th century was Military Walk, a 1,500-foot (460&#160;m) street that connected the former Guion Hall, now the location of the Rudder Theatre Complex, with Sbisa Dining Hall. Lined with oak trees, the avenue provided access to Assembly Hall (1889–1929), Foster Hall (1899–1951), Ross Hall (1891–1955), Gaithright Hall (1876–1933), and Mitchell Hall (1912–1972). The street was closed in 1971. Many of the original trees remain, but buildings, walk ways, and grassy areas were added in place of the street itself.<sup id="cite_ref-esbd_16-0" class="reference"><a href="#cite_note-esbd-16">[16]</a></sup></p>
# <div class="thumb tright">
# <div class="thumbinner" style="width:222px;"><a href="/wiki/File:Texas_A%26M_Tent_Row.jpg" class="image"><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/63/Texas_A%26M_Tent_Row.jpg/220px-Texas_A%26M_Tent_Row.jpg" width="220" height="178" class="thumbimage" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/63/Texas_A%26M_Tent_Row.jpg/330px-Texas_A%26M_Tent_Row.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/63/Texas_A%26M_Tent_Row.jpg/440px-Texas_A%26M_Tent_Row.jpg 2x" data-file-width="540" data-file-height="438" /></a>
# <div class="thumbcaption">
# <div class="magnify"><a href="/wiki/File:Texas_A%26M_Tent_Row.jpg" class="internal" title="Enlarge"></a></div>
# A&amp;M Tent Row in 1910</div>
# </div>
# </div>
# <p>The school began offering an expanded choice of degree programs at the same time that the state legislature and the <a href="/wiki/United_States_Department_of_Agriculture" title="United States Department of Agriculture">United States Department of Agriculture</a> established several services at Texas A&amp;M.<sup id="cite_ref-handbook_6-2" class="reference"><a href="#cite_note-handbook-6">[6]</a></sup> The college was unprepared for the ensuing population growth. For the next ten years, several hundred students lived in tents in a field in the middle of campus.<sup id="cite_ref-liffick_17-0" class="reference"><a href="#cite_note-liffick-17">[17]</a></sup></p>
# <p>In the late 1920s, following the discovery of oil on university lands, Texas A&amp;M and the University of Texas negotiated a settlement for the division of the <a href="/wiki/Permanent_University_Fund" title="Permanent University Fund">Permanent University Fund</a> which enabled A&amp;M to receive one-third of the revenue. This guaranteed wealth enabled A&amp;M to grow and expand.<sup id="cite_ref-handbook_6-3" class="reference"><a href="#cite_note-handbook-6">[6]</a></sup></p>
# <h3><span class="mw-headline" id="World_War_II">World War II</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Campus_of_Texas_A%26M_University&amp;action=edit&amp;section=5" title="Edit section: World War II">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>Enrollment soared after <a href="/wiki/World_War_II" title="World War II">World War II</a> as many former soldiers used the <a href="/wiki/G.I._Bill" title="G.I. Bill">G.I. Bill</a> to further their education. Again unprepared for the growth, between 1949 and 1953 Texas A&amp;M used the former <a href="/wiki/Riverside_Campus" class="mw-redirect" title="Riverside Campus">Bryan Air Force Base</a> as an extension of the campus. An estimated 5,500 men lived, studied, ate, showered, and attended classes at the base, which became known as the Annex.<sup id="cite_ref-gillentine_18-0" class="reference"><a href="#cite_note-gillentine-18">[18]</a></sup></p>
# <h3><span class="mw-headline" id="Late_20th_century">Late 20th century</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Campus_of_Texas_A%26M_University&amp;action=edit&amp;section=6" title="Edit section: Late 20th century">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>The <a href="/wiki/George_Bush_Presidential_Library" title="George Bush Presidential Library">George Bush Presidential Library</a> was established in 1997 on 90 acres (36&#160;ha) of land donated by Texas A&amp;M at the western edge of the campus. This tenth presidential library was built between 1995 and 1997 and contains the presidential and vice-presidential papers of <a href="/wiki/George_H.W._Bush" class="mw-redirect" title="George H.W. Bush">George H.W. Bush</a> and the vice-presidential papers of <a href="/wiki/Dan_Quayle" title="Dan Quayle">Dan Quayle</a>.<sup id="cite_ref-bushmaterials_19-0" class="reference"><a href="#cite_note-bushmaterials-19">[19]</a></sup></p>
# <p>In 1998, activists on campus (including Professor Patrick Slattery) suggested the statue of <a href="/wiki/Lawrence_Sullivan_Ross" title="Lawrence Sullivan Ross">Lawrence Sullivan Ross</a> should be removed on the basis that he was a member of the <a href="/wiki/Ku_Klux_Klan" title="Ku Klux Klan">Ku Klux Klan</a>.<sup id="cite_ref-deconstructingracismslattery_20-0" class="reference"><a href="#cite_note-deconstructingracismslattery-20">[20]</a></sup> Instead, Slattery and others wanted to create a "diversity plaza", with a statue of <a href="/wiki/Matthew_Gaines" title="Matthew Gaines">Matthew Gaines</a>, an African-American politician.<sup id="cite_ref-deconstructingracismslattery_20-1" class="reference"><a href="#cite_note-deconstructingracismslattery-20">[20]</a></sup> The project was abandoned in the wake of the <a href="/wiki/Aggie_Bonfire" title="Aggie Bonfire">Aggie Bonfire</a> tragedy, in 1999.<sup id="cite_ref-deconstructingracismslattery_20-2" class="reference"><a href="#cite_note-deconstructingracismslattery-20">[20]</a></sup></p>
# <h3><span class="mw-headline" id="The_2004_Campus_Master_Plan">The 2004 Campus Master Plan</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Campus_of_Texas_A%26M_University&amp;action=edit&amp;section=7" title="Edit section: The 2004 Campus Master Plan">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>To address the rapid growth of the student body and faculty, Texas A&amp;M created a Campus Master plan that provided guidelines on campus development. The plan created by the architectural firm Barnes Gromatzky Kosarek Architects with Michael Dennis &amp; Associates, was completed in July 2004. The primary goals of the plan were to: reinforce campus identity and community, establish connectivity, create architecture that contributes positively to the campus community, promote spatial equity and appropriateness, promote sustainability, and develop a supportive process to achieve the goals above.<sup id="cite_ref-masterplan_21-0" class="reference"><a href="#cite_note-masterplan-21">[21]</a></sup></p>
# <p>Major components of the plan include</p>
# <ul>
# <li>New Main Drive</li>
# <li>Administration Building/East Lawn Area</li>
# <li>East Quad</li>
# <li>East-West Pedestrian Walks</li>
# <li>Library Quad and Diversity Plaza</li>
# <li>Academic Quad and Military Walk</li>
# <li>Simpson Drill Field and the New Underpasses</li>
# <li>New West Quad and Wellborn Road</li>
# <li>West Campus Extension of Old Main</li>
# <li>White Creek Greenway</li>
# </ul>
# <p>Texas A&amp;M's master plan has won several awards including: Campus Planning Award from the Boston Society of Architects and a 2004 design award from the <a href="/wiki/Texas_Society_of_Architects" title="Texas Society of Architects">Texas Society of Architects</a>.<sup id="cite_ref-masterawards_22-0" class="reference"><a href="#cite_note-masterawards-22">[22]</a></sup></p>
# <h3><span class="mw-headline" id="Current_Status">Current Status</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Campus_of_Texas_A%26M_University&amp;action=edit&amp;section=8" title="Edit section: Current Status">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <div class="thumb tleft">
# <div class="thumbinner" style="width:222px;"><a href="/wiki/File:TAMU_ID_Life_Sciences.JPG" class="image"><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/a1/TAMU_ID_Life_Sciences.JPG/220px-TAMU_ID_Life_Sciences.JPG" width="220" height="146" class="thumbimage" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/a1/TAMU_ID_Life_Sciences.JPG/330px-TAMU_ID_Life_Sciences.JPG 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/a1/TAMU_ID_Life_Sciences.JPG/440px-TAMU_ID_Life_Sciences.JPG 2x" data-file-width="3008" data-file-height="2000" /></a>
# <div class="thumbcaption">
# <div class="magnify"><a href="/wiki/File:TAMU_ID_Life_Sciences.JPG" class="internal" title="Enlarge"></a></div>
# Interdisciplinary Life Sciences building</div>
# </div>
# </div>
# <p>Following the completion of the master plan, Texas A&amp;M has begun some of the largest construction projects in its history. In 2007, the Texas A&amp;M University system had close to 700 million dollars of construction projects planned or already underway in the Bryan College Station area. To fund this expansion, the university is relying on state funding, donations, fees and tuition revenue bonds to cover costs.<sup id="cite_ref-700million_23-0" class="reference"><a href="#cite_note-700million-23">[23]</a></sup></p>
# <p>The first major building of this construction phase, the $95 million 220,000 square feet (20,000&#160;m<sup>2</sup>) <a href="/wiki/Interdisciplinary" class="mw-redirect" title="Interdisciplinary">Interdisciplinary</a> <a href="/wiki/Life_Sciences" class="mw-redirect" title="Life Sciences">Life Sciences</a> building, is the largest building on campus.<sup id="cite_ref-lsbuilding_24-0" class="reference"><a href="#cite_note-lsbuilding-24">[24]</a></sup><sup id="cite_ref-CBatt_25-0" class="reference"><a href="#cite_note-CBatt-25">[25]</a></sup> In addition, Texas A&amp;M is constructed two physics buildings dedicated to astronomical research with funds from a donation by George P. W. Mitchell.<sup id="cite_ref-CBatt_25-1" class="reference"><a href="#cite_note-CBatt-25">[25]</a></sup> From late 2008 to August 2011, Texas A&amp;M constructed a $104 million, Emerging Technologies and Economic Development Interdisciplinary Building.<sup id="cite_ref-700million_23-1" class="reference"><a href="#cite_note-700million-23">[23]</a></sup><sup id="cite_ref-emerging_26-0" class="reference"><a href="#cite_note-emerging-26">[26]</a></sup> Outside of main campus, Texas A&amp;M Health Science Center is constructing a new campus on 200 acres (810,000&#160;m<sup>2</sup>) in Bryan, Texas.<sup id="cite_ref-700million_23-2" class="reference"><a href="#cite_note-700million-23">[23]</a></sup> The first building on this new campus opened in 2010.<sup id="cite_ref-HSCcampus_27-0" class="reference"><a href="#cite_note-HSCcampus-27">[27]</a></sup><sup id="cite_ref-TAMUHSC2_28-0" class="reference"><a href="#cite_note-TAMUHSC2-28">[28]</a></sup> On December 16, 2010, Texas A&amp;M broke ground on a new Humanities and Arts building. This building is especially notable because of the institution's "historical focus on engineering and agriculture".<sup id="cite_ref-Arts1_29-0" class="reference"><a href="#cite_note-Arts1-29">[29]</a></sup><sup id="cite_ref-Arts2_30-0" class="reference"><a href="#cite_note-Arts2-30">[30]</a></sup><sup id="cite_ref-Arts3_31-0" class="reference"><a href="#cite_note-Arts3-31">[31]</a></sup> The school finished renovations and reopened on the Memorial Student Center on April 21, 2012.<sup id="cite_ref-MSC_renovation_32-0" class="reference"><a href="#cite_note-MSC_renovation-32">[32]</a></sup></p>
# <p>In addition to academic facilities, athletics director <a href="/wiki/Bill_Byrne_(athletic_director)" title="Bill Byrne (athletic director)">Bill Byrne</a> has overseen an aggressive expansion of the university's sports faculties since his hiring in 2003. Under his leadership, Texas A&amp;M completed several athletics facilities including the McFerrin Athletic Center, an indoor <a href="/wiki/American_football" title="American football">football</a> practice field and track and field facility. The center was host of the 2009 NCAA Indoor Championships.<sup id="cite_ref-TrackChamp_33-0" class="reference"><a href="#cite_note-TrackChamp-33">[33]</a></sup> The department has also completed the <a href="/wiki/Reed_Arena#Cox-McFerrin_Center" title="Reed Arena">Cox-McFerrin Center</a>, a practice facility for the <a href="/wiki/Texas_A%26M_Aggies_men%27s_basketball" title="Texas A&amp;M Aggies men's basketball">men's</a> and <a href="/wiki/Texas_A%26M_Aggies_women%27s_basketball" title="Texas A&amp;M Aggies women's basketball">women's</a> basketball teams. The school recently renovated the schools baseball stadium, Olsen Field, with a name change to Olsen Field at Blue Bell Park following a $7 million donation from <a href="/wiki/Blue_Bell_Creameries" title="Blue Bell Creameries">Blue Bell Creameries</a>. The field was reopened on February 17, 2012.<sup id="cite_ref-expansion1_34-0" class="reference"><a href="#cite_note-expansion1-34">[34]</a></sup><sup id="cite_ref-expansion2_35-0" class="reference"><a href="#cite_note-expansion2-35">[35]</a></sup><sup id="cite_ref-expansion3_36-0" class="reference"><a href="#cite_note-expansion3-36">[36]</a></sup> Future plans include the renovation of Kyle field.</p>
# <h2><span class="mw-headline" id="Areas">Areas</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Campus_of_Texas_A%26M_University&amp;action=edit&amp;section=9" title="Edit section: Areas">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <h3><span class="mw-headline" id="Main_Campus">Main Campus</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Campus_of_Texas_A%26M_University&amp;action=edit&amp;section=10" title="Edit section: Main Campus">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>The main campus chiefly contains the student and <a href="/wiki/Texas_A%26M_University_Corps_of_Cadets" title="Texas A&amp;M University Corps of Cadets">Corps of Cadets</a> dormitories, university apartments, various dining facilities, a health center, a post office, libraries, a university-operated golf course, and drill fields used by the Corps. The main campus houses some facilities of the <a href="/wiki/Texas_A%26M_College_of_Science" title="Texas A&amp;M College of Science">College of Sciences</a> and all of the facilities of the <a href="/wiki/Texas_A%26M_College_of_Architecture" title="Texas A&amp;M College of Architecture">College of Architecture</a>, the <a href="/wiki/Texas_A%26M_College_of_Education_and_Human_Development" class="mw-redirect" title="Texas A&amp;M College of Education and Human Development">College of Education and Human Development</a>, the <a href="/wiki/Texas_A%26M_College_of_Geosciences" title="Texas A&amp;M College of Geosciences">College of Geosciences</a>, the <a href="/wiki/Texas_A%26M_College_of_Liberal_Arts" class="mw-redirect" title="Texas A&amp;M College of Liberal Arts">College of Liberal Arts</a>, and the <a href="/wiki/Dwight_Look_College_of_Engineering" title="Dwight Look College of Engineering">Dwight Look College of Engineering</a>. Notable buildings on the main campus include Kyle Field, the Academic Building, the Memorial Student Center, the Administration Building, Rudder Tower, Albritton Bell Tower, and the <a href="/wiki/Bonfire_Memorial" class="mw-redirect" title="Bonfire Memorial">Bonfire Memorial</a>. The main campus is bordered by George Bush Drive, Wellborn Drive, University Drive, and Texas Avenue on the south, west, north, and east sides, respectively.<sup id="cite_ref-CampusMaps_37-0" class="reference"><a href="#cite_note-CampusMaps-37">[37]</a></sup></p>
# <div class="center">
# <div class="thumb tnone">
# <div class="thumbinner" style="width:602px;"><a href="/wiki/File:Pano_main_campus.jpg" class="image"><img alt="" src="//upload.wikimedia.org/wikipedia/en/thumb/5/57/Pano_main_campus.jpg/600px-Pano_main_campus.jpg" width="600" height="142" class="thumbimage" srcset="//upload.wikimedia.org/wikipedia/en/thumb/5/57/Pano_main_campus.jpg/900px-Pano_main_campus.jpg 1.5x, //upload.wikimedia.org/wikipedia/en/5/57/Pano_main_campus.jpg 2x" data-file-width="949" data-file-height="224" /></a>
# <div class="thumbcaption">
# <div class="magnify"><a href="/wiki/File:Pano_main_campus.jpg" class="internal" title="Enlarge"></a></div>
# A view of the main campus as viewed from The Zone at Kyle Field</div>
# </div>
# </div>
# </div>
# <h3><span class="mw-headline" id="East_Campus">East Campus</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Campus_of_Texas_A%26M_University&amp;action=edit&amp;section=11" title="Edit section: East Campus">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>The eastern region of campus, or "East Campus," is commonly cited as beginning to the east of Evans library and continuing to the Texas Avenue border of Texas A&amp;M University's College Station campus. Buildings on this side of campus include the majority of architecture buildings as well as a few engineering buildings and the administration building.</p>
# <h3><span class="mw-headline" id="West_Campus">West Campus</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Campus_of_Texas_A%26M_University&amp;action=edit&amp;section=12" title="Edit section: West Campus">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>The west campus contains both the <a href="/wiki/Texas_A%26M_College_of_Veterinary_Medicine_%26_Biomedical_Sciences" title="Texas A&amp;M College of Veterinary Medicine &amp; Biomedical Sciences">College of Veterinary Medicine</a> and the <a href="/wiki/Texas_A%26M_Health_Science_Center" title="Texas A&amp;M Health Science Center">Health Science Center</a>, a component of the <a href="/wiki/Texas_A%26M_University_System" title="Texas A&amp;M University System">Texas A&amp;M University System</a>. West campus also contains some facilities of the College of Sciences, the new facilities of the <a href="/wiki/Texas_A%26M_College_of_Agriculture_and_Life_Sciences" title="Texas A&amp;M College of Agriculture and Life Sciences">College of Agriculture and Life Sciences</a> (relocated in 2011), all of the facilities of the <a href="/wiki/George_Bush_School_of_Government_and_Public_Service" class="mw-redirect" title="George Bush School of Government and Public Service">George Bush School of Government and Public Service</a>, and <a href="/wiki/Mays_Business_School" title="Mays Business School">Mays Business School</a>. In addition to a few dining facilities, the Medical Sciences Library and the West Campus Library are the only two libraries on west campus. <a href="/wiki/Olsen_Field" class="mw-redirect" title="Olsen Field">Olsen Field</a>, home of the baseball team, and <a href="/wiki/Reed_Arena" title="Reed Arena">Reed Arena</a>, home of the basketball team, are both situated on west campus as well. In addition, administrative offices of various state agencies, including the <a href="/wiki/Texas_Engineering_Extension_Service" class="mw-redirect" title="Texas Engineering Extension Service">Texas Engineering Extension Service</a> and <a href="/wiki/Texas_Transportation_Institute" class="mw-redirect" title="Texas Transportation Institute">Texas Transportation Institute</a>, are housed here. <a href="/wiki/Easterwood_Airport" title="Easterwood Airport">Easterwood Airport</a>, which provides flights to both <a href="/wiki/George_Bush_Intercontinental_Airport" title="George Bush Intercontinental Airport">George Bush Intercontinental Airport</a> and <a href="/wiki/Dallas-Fort_Worth_International_Airport" class="mw-redirect" title="Dallas-Fort Worth International Airport">Dallas-Fort Worth International Airport</a>, is located on the far west side of west campus. West Campus is bordered by railroad tracks operated by <a href="/wiki/Union_Pacific_Railroad" title="Union Pacific Railroad">Union Pacific Railroad</a>, George Bush Drive, John Kimbrough Boulevard, and Easterwood Airport, on the east, south, north, and west sides, respectively.<sup id="cite_ref-CampusMaps_37-1" class="reference"><a href="#cite_note-CampusMaps-37">[37]</a></sup></p>
# <h3><span class="mw-headline" id="Riverside_Campus">Riverside Campus</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Campus_of_Texas_A%26M_University&amp;action=edit&amp;section=13" title="Edit section: Riverside Campus">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <div role="note" class="hatnote">Main article: <a href="/wiki/Bryan_Air_Force_Base" title="Bryan Air Force Base">Bryan Air Force Base</a></div>
# <p>The Riverside Campus is located adjacent to State Highway 47 and Highway 21, west of <a href="/wiki/Bryan,_Texas" title="Bryan, Texas">Bryan, Texas</a>. Riverside Campus was originally Bryan Army Airfield.<sup id="cite_ref-HandbookofTexas_38-0" class="reference"><a href="#cite_note-HandbookofTexas-38">[38]</a></sup> The base became <a href="/wiki/Bryan_Air_Force_Base" title="Bryan Air Force Base">Bryan Air Force Base</a> upon separation of the Air Force from the Army in 1947.<sup id="cite_ref-HandbookofTexas_38-1" class="reference"><a href="#cite_note-HandbookofTexas-38">[38]</a></sup> Following World War II, enrollment at Texas A&amp;M soared. Housing was in short supply, so between 1949 and 1953 an estimated 5,500 men lived, studied, ate, showered, and attended classes at the Annex on the former Bryan Air Force Base,<sup id="cite_ref-gillentine_18-1" class="reference"><a href="#cite_note-gillentine-18">[18]</a></sup> which was deactivated in May 1961. The land and buildings were deeded to the Agricultural and Mechanical College of Texas (now Texas A&amp;M University) in 1962.<sup id="cite_ref-HandbookofTexas_38-2" class="reference"><a href="#cite_note-HandbookofTexas-38">[38]</a></sup></p>
# <div class="thumb tleft">
# <div class="thumbinner" style="width:222px;"><a href="/wiki/File:Riverside_Campus.JPG" class="image"><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/cc/Riverside_Campus.JPG/220px-Riverside_Campus.JPG" width="220" height="160" class="thumbimage" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/cc/Riverside_Campus.JPG/330px-Riverside_Campus.JPG 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/cc/Riverside_Campus.JPG/440px-Riverside_Campus.JPG 2x" data-file-width="957" data-file-height="696" /></a>
# <div class="thumbcaption">
# <div class="magnify"><a href="/wiki/File:Riverside_Campus.JPG" class="internal" title="Enlarge"></a></div>
# Satellite image of the Riverside Campus</div>
# </div>
# </div>
# <p>Situated 10 miles (16&#160;km) from the main campus, the 1,900-acre (8&#160;km<sup>2</sup>) Riverside Campus hosts three training divisions of the <a href="/wiki/TEEX" class="mw-redirect" title="TEEX">Texas Engineering Extension Service</a> (TEEX), which occupies about 100,000 square feet (10,000&#160;m<sup>2</sup>) of offices, classrooms, and laboratories. The agency maintains outdoor training facilities at Riverside, including overhead and underground electric power training fields, a firing range for law enforcement officers, a heavy equipment training field, an emergency vehicle-driving track, unexploded ordnance ranges and search grids, and simulation prop houses for tactical training.<sup id="cite_ref-TEEX_39-0" class="reference"><a href="#cite_note-TEEX-39">[39]</a></sup><sup id="cite_ref-40" class="reference"><a href="#cite_note-40">[40]</a></sup></p>
# ...
# 							</div>
# 		</div>
# 		<div id="mw-navigation">
# 			<h2>Navigation menu</h2>
#
# 			<div id="mw-head">
# 									<div id="p-personal" role="navigation" class="" aria-labelledby="p-personal-label">
# 						<h3 id="p-personal-label">Personal tools</h3>
# 						<ul>
# 							<li id="pt-anonuserpage">Not logged in</li><li id="pt-anontalk"><a href="/wiki/Special:MyTalk" title="Discussion about edits from this IP address [n]" accesskey="n">Talk</a></li><li id="pt-anoncontribs"><a href="/wiki/Special:MyContributions" title="A list of edits made from this IP address [y]" accesskey="y">Contributions</a></li><li id="pt-createaccount"><a href="/w/index.php?title=Special:CreateAccount&amp;returnto=Campus+of+Texas+A%26M+University" title="You are encouraged to create an account and log in; however, it is not mandatory">Create account</a></li><li id="pt-login"><a href="/w/index.php?title=Special:UserLogin&amp;returnto=Campus+of+Texas+A%26M+University" title="You're encouraged to log in; however, it's not mandatory. [o]" accesskey="o">Log in</a></li>						</ul>
# 					</div>
# 									<div id="left-navigation">
# 										<div id="p-namespaces" role="navigation" class="vectorTabs" aria-labelledby="p-namespaces-label">
# 						<h3 id="p-namespaces-label">Namespaces</h3>
# 						<ul>
# 															<li  id="ca-nstab-main" class="selected"><span><a href="/wiki/Campus_of_Texas_A%26M_University"  title="View the content page [c]" accesskey="c">Article</a></span></li>
# 															<li  id="ca-talk"><span><a href="/wiki/Talk:Campus_of_Texas_A%26M_University"  title="Discussion about the content page [t]" accesskey="t" rel="discussion">Talk</a></span></li>
# 													</ul>
# 					</div>
# 										<div id="p-variants" role="navigation" class="vectorMenu emptyPortlet" aria-labelledby="p-variants-label">
# 												<h3 id="p-variants-label">
# 							<span>Variants</span><a href="#"></a>
# 						</h3>
#
# 						<div class="menu">
# 							<ul>
# 															</ul>
# 						</div>
# 					</div>
# 									</div>
# 				<div id="right-navigation">
# 										<div id="p-views" role="navigation" class="vectorTabs" aria-labelledby="p-views-label">
# 						<h3 id="p-views-label">Views</h3>
# 						<ul>
# 															<li id="ca-view" class="selected"><span><a href="/wiki/Campus_of_Texas_A%26M_University" >Read</a></span></li>
# 															<li id="ca-edit"><span><a href="/w/index.php?title=Campus_of_Texas_A%26M_University&amp;action=edit"  title="Edit this page [e]" accesskey="e">Edit</a></span></li>
# 															<li id="ca-history" class="collapsible"><span><a href="/w/index.php?title=Campus_of_Texas_A%26M_University&amp;action=history"  title="Past revisions of this page [h]" accesskey="h">View history</a></span></li>
# 													</ul>
# 					</div>
# 										<div id="p-cactions" role="navigation" class="vectorMenu emptyPortlet" aria-labelledby="p-cactions-label">
# 						<h3 id="p-cactions-label"><span>More</span><a href="#"></a></h3>
#
# 						<div class="menu">
# 							<ul>
# 															</ul>
# 						</div>
# 					</div>
# 										<div id="p-search" role="search">
# 						<h3>
# 							<label for="searchInput">Search</label>
# 						</h3>
#
# 						<form action="/w/index.php" id="searchform">
# 							<div id="simpleSearch">
# 							<input type="search" name="search" placeholder="Search Wikipedia" title="Search Wikipedia [f]" accesskey="f" id="searchInput"/><input type="hidden" value="Special:Search" name="title"/><input type="submit" name="fulltext" value="Search" title="Search Wikipedia for this text" id="mw-searchButton" class="searchButton mw-fallbackSearchButton"/><input type="submit" name="go" value="Go" title="Go to a page with this exact name if it exists" id="searchButton" class="searchButton"/>							</div>
# 						</form>
# 					</div>
# 									</div>
# 			</div>
# 			<div id="mw-panel">
# 				<div id="p-logo" role="banner"><a class="mw-wiki-logo" href="/wiki/Main_Page"  title="Visit the main page"></a></div>
# 						<div class="portal" role="navigation" id='p-navigation' aria-labelledby='p-navigation-label'>
# 			<h3 id='p-navigation-label'>Navigation</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="n-mainpage-description"><a href="/wiki/Main_Page" title="Visit the main page [z]" accesskey="z">Main page</a></li><li id="n-contents"><a href="/wiki/Portal:Contents" title="Guides to browsing Wikipedia">Contents</a></li><li id="n-featuredcontent"><a href="/wiki/Portal:Featured_content" title="Featured content – the best of Wikipedia">Featured content</a></li><li id="n-currentevents"><a href="/wiki/Portal:Current_events" title="Find background information on current events">Current events</a></li><li id="n-randompage"><a href="/wiki/Special:Random" title="Load a random article [x]" accesskey="x">Random article</a></li><li id="n-sitesupport"><a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us">Donate to Wikipedia</a></li><li id="n-shoplink"><a href="//shop.wikimedia.org" title="Visit the Wikipedia store">Wikipedia store</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-interaction' aria-labelledby='p-interaction-label'>
# 			<h3 id='p-interaction-label'>Interaction</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="n-help"><a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia">Help</a></li><li id="n-aboutsite"><a href="/wiki/Wikipedia:About" title="Find out about Wikipedia">About Wikipedia</a></li><li id="n-portal"><a href="/wiki/Wikipedia:Community_portal" title="About the project, what you can do, where to find things">Community portal</a></li><li id="n-recentchanges"><a href="/wiki/Special:RecentChanges" title="A list of recent changes in the wiki [r]" accesskey="r">Recent changes</a></li><li id="n-contactpage"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia">Contact page</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-tb' aria-labelledby='p-tb-label'>
# 			<h3 id='p-tb-label'>Tools</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="t-whatlinkshere"><a href="/wiki/Special:WhatLinksHere/Campus_of_Texas_A%26M_University" title="List of all English Wikipedia pages containing links to this page [j]" accesskey="j">What links here</a></li><li id="t-recentchangeslinked"><a href="/wiki/Special:RecentChangesLinked/Campus_of_Texas_A%26M_University" rel="nofollow" title="Recent changes in pages linked from this page [k]" accesskey="k">Related changes</a></li><li id="t-upload"><a href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]" accesskey="u">Upload file</a></li><li id="t-specialpages"><a href="/wiki/Special:SpecialPages" title="A list of all special pages [q]" accesskey="q">Special pages</a></li><li id="t-permalink"><a href="/w/index.php?title=Campus_of_Texas_A%26M_University&amp;oldid=767577617" title="Permanent link to this revision of the page">Permanent link</a></li><li id="t-info"><a href="/w/index.php?title=Campus_of_Texas_A%26M_University&amp;action=info" title="More information about this page">Page information</a></li><li id="t-wikibase"><a href="https://www.wikidata.org/wiki/Q5028713" title="Link to connected data repository item [g]" accesskey="g">Wikidata item</a></li><li id="t-cite"><a href="/w/index.php?title=Special:CiteThisPage&amp;page=Campus_of_Texas_A%26M_University&amp;id=767577617" title="Information on how to cite this page">Cite this page</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-coll-print_export' aria-labelledby='p-coll-print_export-label'>
# 			<h3 id='p-coll-print_export-label'>Print/export</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="coll-create_a_book"><a href="/w/index.php?title=Special:Book&amp;bookcmd=book_creator&amp;referer=Campus+of+Texas+A%26M+University">Create a book</a></li><li id="coll-download-as-rdf2latex"><a href="/w/index.php?title=Special:Book&amp;bookcmd=render_article&amp;arttitle=Campus+of+Texas+A%26M+University&amp;returnto=Campus+of+Texas+A%26M+University&amp;oldid=767577617&amp;writer=rdf2latex">Download as PDF</a></li><li id="t-print"><a href="/w/index.php?title=Campus_of_Texas_A%26M_University&amp;printable=yes" title="Printable version of this page [p]" accesskey="p">Printable version</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-lang' aria-labelledby='p-lang-label'>
# 			<h3 id='p-lang-label'>Languages</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li class="interlanguage-link interwiki-zh"><a href="https://zh.wikipedia.org/wiki/%E5%BE%B7%E5%B7%9E%E8%BE%B2%E5%B7%A5%E5%A4%A7%E5%AD%B8%E6%A0%A1%E5%9C%92" title="德州農工大學校園 – Chinese" lang="zh" hreflang="zh" class="interlanguage-link-target">中文</a></li>					</ul>
# 				<div class='after-portlet after-portlet-lang'><span class="wb-langlinks-edit wb-langlinks-link"><a href="https://www.wikidata.org/wiki/Q5028713#sitelinks-wikipedia" title="Edit interlanguage links" class="wbc-editpage">Edit links</a></span></div>			</div>
# 		</div>
# 				</div>
# 		</div>
# 		<div id="footer" role="contentinfo">
# 							<ul id="footer-info">
# 											<li id="footer-info-lastmod"> This page was last modified on 26 February 2017, at 18:43.</li>
# 											<li id="footer-info-copyright">Text is available under the <a rel="license" href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License">Creative Commons Attribution-ShareAlike License</a><a rel="license" href="//creativecommons.org/licenses/by-sa/3.0/" style="display:none;"></a>;
# additional terms may apply.  By using this site, you agree to the <a href="//wikimediafoundation.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//wikimediafoundation.org/wiki/Privacy_policy">Privacy Policy</a>. Wikipedia® is a registered trademark of the <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>
# 									</ul>
# 							<ul id="footer-places">
# 											<li id="footer-places-privacy"><a href="https://wikimediafoundation.org/wiki/Privacy_policy" class="extiw" title="wmf:Privacy policy">Privacy policy</a></li>
# 											<li id="footer-places-about"><a href="/wiki/Wikipedia:About" title="Wikipedia:About">About Wikipedia</a></li>
# 											<li id="footer-places-disclaimer"><a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">Disclaimers</a></li>
# 											<li id="footer-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>
# 											<li id="footer-places-developers"><a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">Developers</a></li>
# 											<li id="footer-places-cookiestatement"><a href="https://wikimediafoundation.org/wiki/Cookie_statement">Cookie statement</a></li>
# 											<li id="footer-places-mobileview"><a href="//en.m.wikipedia.org/w/index.php?title=Campus_of_Texas_A%26M_University&amp;mobileaction=toggle_view_mobile" class="noprint stopMobileRedirectToggle">Mobile view</a></li>
# 									</ul>
# 										<ul id="footer-icons" class="noprint">
# 											<li id="footer-copyrightico">
# 							<a href="https://wikimediafoundation.org/"><img src="/static/images/wikimedia-button.png" srcset="/static/images/wikimedia-button-1.5x.png 1.5x, /static/images/wikimedia-button-2x.png 2x" width="88" height="31" alt="Wikimedia Foundation"/></a>						</li>
# 											<li id="footer-poweredbyico">
# 							<a href="//www.mediawiki.org/"><img src="/static/images/poweredby_mediawiki_88x31.png" alt="Powered by MediaWiki" srcset="/static/images/poweredby_mediawiki_132x47.png 1.5x, /static/images/poweredby_mediawiki_176x62.png 2x" width="88" height="31"/></a>						</li>
# 									</ul>
# 						<div style="clear:both"></div>
# 		</div>
# 		<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.940","walltime":"1.044","ppvisitednodes":{"value":6709,"limit":1000000},"ppgeneratednodes":{"value":0,"limit":1500000},"postexpandincludesize":{"value":240342,"limit":2097152},"templateargumentsize":{"value":17941,"limit":2097152},"expansiondepth":{"value":15,"limit":40},"expensivefunctioncount":{"value":8,"limit":500},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00%  906.317      1 -total"," 64.85%  587.775      1 Template:Reflist"," 25.51%  231.177     53 Template:Cite_web"," 11.83%  107.176     22 Template:Cite_news","  9.53%   86.360     16 Template:Dead_link","  7.41%   67.174     16 Template:Fix","  7.08%   64.175      1 Template:Texas_A\u0026amp;M_University","  6.83%   61.889      1 Template:Navbox_with_collapsible_groups","  6.36%   57.677     32 Template:Category_handler","  5.95%   53.884     13 Template:Convert"]},"scribunto":{"limitreport-timeusage":{"value":"0.503","limit":"10.000"},"limitreport-memusage":{"value":7990521,"limit":52428800}},"cachereport":{"origin":"mw1211","timestamp":"20170302072003","ttl":2592000,"transientcontent":false}}});});</script><script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":1130,"wgHostname":"mw1211"});});</script>
# 	</body>
# </html>

# %% [markdown]
# ## Reading in the Data
#
# It appears that the main content is nested inside the div tag with the id content.
#
#
# Read all of the files into list called content.
# Each value in the list should contain the content of a file.
# Create a list called articles that contains the article names.
# These should be the filename without the wiki/ prefix, and the .html suffix.
# Experiment with different performance options, and write up your findings.

# %%
import concurrent.futures
import time

pool = concurrent.futures.ThreadPoolExecutor(max_workers=2)

def read_data(filename):
    with open(filename) as f:
        data = f.read()
    return data

start = time.time()
filenames = ["wiki/{}".format(f) for f in os.listdir("wiki")]
content = pool.map(read_data, filenames)
content = list(content)

end = time.time()
print(end - start)
articles = [f.replace(".html", "").replace("wiki/", "") for f in filenames]
# Out:
# 0.23008227348327637

# %% [markdown]
# After doing some profiling, it doesn't appear that threading makes a huge difference to performance. It may be because although files are opened, most of the time saved is offset by the overhead of creating new threads.

# %% [markdown]
# ## Remove Extraneous Markup
#
# Using the BeautifulSoup package, we'll parse each wiki article, then extract the div with id content and everything inside it.
#
# Since this operation is more CPU intensive than before, let's try using a process pool to see if the speed improves.

# %%
from bs4 import BeautifulSoup

def parse_html(html):
    soup = BeautifulSoup(html, 'html.parser')
    return str(soup.find_all("div", id="content")[0])

start = time.time()
pool = concurrent.futures.ProcessPoolExecutor(max_workers=3)
parsed = pool.map(parse_html, content)
parsed = list(parsed)
end = time.time()

print(end - start)
# Out:
# 26.994540691375732

# %% [markdown]
# This operation is quite slow and CPU-intensive. It looks like using as many processes are there are available processors speeds things up.

# %% [markdown]
# ## Finding Common Tags
#
# Now that we've extracted the main part of each page, let's count up how many times each tag occurs. This will give us clues about how Wikipedia pages are typically structured. For example, if there are a lot of a tags on each page, we know that Wikipedia articles tend to be very connected to other articles or pages. On the other hand, a lot of div tags will tell us that Wikipedia pages tend to have a nested structure with many page elements.

# %%
from bs4 import BeautifulSoup

def count_tags(html):
    soup = BeautifulSoup(html, 'html.parser')
    tags = {}
    for tag in soup.find_all():
        if tag.name not in tags:
            tags[tag.name] = 0
        tags[tag.name] += 1
    return tags

start = time.time()
pool = concurrent.futures.ProcessPoolExecutor(max_workers=3)
tags = pool.map(count_tags, parsed)
tags = list(tags)

tag_counts = {}
for tag in tags:
    for k,v in tag.items():
        if k not in tag_counts:
            tag_counts[k] = 0
        tag_counts[k] += v
end = time.time()

print(end - start)
tag_counts
# Out:
# 13.91459345817566
# {'a': 161065,
#  'abbr': 3665,
#  'annotation': 2,
#  'area': 39,
#  'audio': 2,
#  'b': 14455,
#  'bdi': 4,
#  'big': 75,
#  'blockquote': 58,
#  'br': 4986,
#  'caption': 200,
#  'center': 64,
#  'cite': 3563,
#  'code': 108,
#  'dd': 1376,
#  'del': 2,
#  'div': 28581,
#  'dl': 457,
#  'dt': 334,
#  'font': 40,
#  'h1': 999,
#  'h2': 4045,
#  'h3': 777,
#  'h4': 117,
#  'h5': 4,
#  'h6': 1,
#  'hr': 51,
#  'i': 18246,
#  'img': 6701,
#  'li': 85779,
#  'map': 2,
#  'math': 2,
#  'mo': 2,
#  'mrow': 2,
#  'mstyle': 2,
#  'noscript': 999,
#  'ol': 858,
#  'p': 7998,
#  'pre': 1,
#  'q': 76,
#  'rb': 16,
#  'rp': 32,
#  'rt': 16,
#  'ruby': 16,
#  's': 10,
#  'samp': 2,
#  'semantics': 2,
#  'small': 3272,
#  'source': 2,
#  'span': 67350,
#  'strong': 599,
#  'sub': 151,
#  'sup': 11157,
#  'table': 4010,
#  'td': 57673,
#  'th': 14472,
#  'tr': 27300,
#  'u': 51,
#  'ul': 10972,
#  'wbr': 85}

# %% [markdown]
# Based on our findings, it looks like there are quite a few td, a, li, and span tags. This indicates that articles tend to have lots of links, along with lists and tables. Links are the most numerous tag, which indicates the interconnected nature of articles on Wikipedia.

# %% [markdown]
# ## Finding Common Words
#
# After finding the common tags, we should be able to find the common words in the article body. We can apply any definition of "word" that we want, but it might be helpful to apply similar criteria to what we saw in the last mission.
#
# One thing to be aware of here is that depending on the words you choose, you may run out of memory, or performance may be slow. Try tweaking things to improve performance.

# %%
from bs4 import BeautifulSoup
from collections import Counter
import re

def count_words(html):
    soup = BeautifulSoup(html, 'html.parser')
    words = {}
    text = soup.get_text()
    text = re.sub("\W+", " ", text.lower())
    words = text.split(" ")
    words = [w for w in words if len(w) >= 5]
    return Counter(words).most_common(15)

start = time.time()
pool = concurrent.futures.ProcessPoolExecutor(max_workers=3)
words = pool.map(count_words, parsed)
words = list(words)

word_counts = {}
for wc in words:
    for word, count in wc:
        if word not in word_counts:
            word_counts[word] = 0
        word_counts[word] += 1
end = time.time()

print(end - start)
word_counts
# Out:
# 14.085181474685669
# {'third': 4,
#  'archetypal': 1,
#  'medalist': 2,
#  'ryfylkeheiane': 1,
#  'swept': 1,
#  'morris': 3,
#  'rendered': 1,
#  'switzerland': 6,
#  'povolný': 1,
#  'margin': 1,
#  'battalion': 1,
#  'border': 3,
#  'period': 3,
#  'arxiv': 1,
#  'omiodes': 1,
#  'navigo': 1,
#  'auxiliary': 1,
#  'mumbai': 3,
#  'floor': 3,
#  'guitarist': 1,
#  'cotton': 1,
#  'least': 4,
#  'mother': 1,
#  'italy': 7,
#  'supermoon': 1,
#  'process': 2,
#  'bundesliga': 2,
#  'rapid': 2,
#  'geezer': 1,
#  'reefs': 1,
#  'systems': 7,
#  'riding': 1,
#  'hepatitis': 1,
#  'vivian': 1,
#  'judges': 1,
#  'creek': 11,
#  'foliar': 1,
#  'streatfields': 1,
#  'jeeva': 1,
#  'seyyed': 2,
#  '01333': 1,
#  'chitradurga': 1,
#  'suffragan': 1,
#  'aomori': 1,
#  'solid': 1,
#  'pathania': 1,
#  'amazon': 2,
#  'revolt': 1,
#  'barros': 1,
#  'bombay': 1,
#  'yasmin': 1,
#  'smilax': 1,
#  'thamesmead': 1,
#  'gornje': 1,
#  'incubus': 1,
#  'score': 7,
#  '13833': 1,
#  'pterygota': 1,
#  'count': 1,
#  'forces': 4,
#  'williams': 9,
#  'ståhlberg': 1,
#  'yaddo': 1,
#  'image': 5,
#  'bells': 1,
#  'kjetil': 1,
#  'studied': 1,
#  'candidate': 4,
#  'character': 4,
#  'cantonment': 1,
#  'epidendreae': 1,
#  'bears': 1,
#  'elaiasome': 1,
#  'consort': 1,
#  'thailavaram': 1,
#  'weight': 1,
#  'cenopis': 1,
#  'epirus': 1,
#  'philanthropist': 1,
#  'avenira': 1,
#  'stress': 1,
#  'mérida': 1,
#  'barnstable': 1,
#  'burning': 1,
#  'refugee': 1,
#  'pictograms': 1,
#  'hapten': 1,
#  'submarine': 1,
#  'field': 11,
#  'rivers': 3,
#  'censor': 1,
#  'toxicity': 1,
#  'teshio': 1,
#  'rodanthe': 1,
#  'basin': 3,
#  'google': 4,
#  'senior': 7,
#  'pablo': 1,
#  'fuchs': 1,
#  'shopping': 1,
#  'englewood': 1,
#  'savannah': 1,
#  'forests': 1,
#  'construction': 4,
#  'cesaris': 1,
#  '000000001989': 1,
#  'huston': 1,
#  'montreal': 3,
#  'jezebel': 1,
#  'yorosso': 1,
#  'bluegrass': 1,
#  'entire': 1,
#  'county': 76,
#  'called': 6,
#  'simone': 1,
#  'atriopeptin': 1,
#  'archaeological': 2,
#  'geography': 11,
#  '51333': 1,
#  'route': 6,
#  'bottle': 1,
#  'guerreiroi': 1,
#  'mohammad': 3,
#  'subdivision': 1,
#  'kavar': 1,
#  'jardim': 1,
#  '23833': 1,
#  'fisher': 2,
#  'eyespots': 1,
#  'stations': 14,
#  'sangro': 1,
#  'horace': 2,
#  'ibrahim': 1,
#  'holland': 1,
#  'bueno': 1,
#  'pastime': 1,
#  'blago': 1,
#  'blacks': 1,
#  'industrial': 3,
#  'mobiasbanca': 1,
#  'mahmudabad': 2,
#  'lithophila': 1,
#  'graphics': 1,
#  'partisan': 1,
#  'khaleh': 2,
#  'naval': 5,
#  'cricket': 8,
#  'river': 18,
#  'zehutinternational': 1,
#  'finishes': 1,
#  'brewery': 1,
#  'boogie': 2,
#  '61306': 1,
#  'nykjær': 1,
#  'felke': 1,
#  'singing': 3,
#  'heart': 1,
#  'parade': 2,
#  'gaming': 1,
#  'episode': 3,
#  'vanuatu': 1,
#  'panchamrutham': 1,
#  'births1948': 1,
#  'purpose': 2,
#  'maddrell': 1,
#  'costa': 1,
#  'carew': 1,
#  'cordray': 1,
#  'orman': 1,
#  'insulin': 1,
#  'unclear': 1,
#  'roque': 1,
#  'accessed': 5,
#  'bombing': 1,
#  'unpaid': 1,
#  'slack': 1,
#  'hartig': 1,
#  'subprefecture': 2,
#  'networking': 1,
#  'sotomayer': 1,
#  'endre': 1,
#  'youngstown': 1,
#  'citation': 4,
#  'books': 4,
#  '66917': 1,
#  'ranga': 1,
#  'entrance': 1,
#  'adjutant': 1,
#  'beckett': 1,
#  'walsingham': 1,
#  'magher': 1,
#  '0000april': 1,
#  'amphibians': 1,
#  'injury': 1,
#  'hester': 1,
#  'formula': 4,
#  'congo': 1,
#  'ocean': 2,
#  'judah': 1,
#  'metallica': 2,
#  'felderman': 1,
#  'wikipedia': 393,
#  'bogan': 1,
#  'national': 45,
#  'pradesh': 3,
#  'corporation': 3,
#  'suoju': 1,
#  'visit': 1,
#  'shelled': 1,
#  'hesleyside': 1,
#  'lorenzo': 1,
#  'disciple': 1,
#  'engineering': 9,
#  'romanticos': 1,
#  'badea': 1,
#  'mccallum': 1,
#  'grandma': 1,
#  'lecithocera': 1,
#  'donoghue': 1,
#  'reading': 1,
#  'mental': 2,
#  'actors': 1,
#  'buddhist': 2,
#  'wreck': 1,
#  'diptera': 1,
#  'modeling': 2,
#  'karkanis': 1,
#  'insectivorous': 1,
#  'russell': 3,
#  'factory': 2,
#  'blutsch': 1,
#  'weekly': 3,
#  'pembroke': 2,
#  'olivaceous': 1,
#  'herbert': 1,
#  'okoye': 1,
#  'serena': 1,
#  'homes': 1,
#  'frescoes': 1,
#  'isidro': 1,
#  'profile': 2,
#  'learning': 1,
#  'panic': 1,
#  'moths': 3,
#  'kamakhyanagar': 1,
#  'runestones': 1,
#  'gorski': 1,
#  'spouse': 1,
#  'straloch': 1,
#  'dante': 1,
#  'disorder': 1,
#  'mohamed': 2,
#  'carthage': 1,
#  'philadelphia': 1,
#  'soltis': 1,
#  'borough': 1,
#  'torremocha': 1,
#  'editor': 2,
#  'empty': 11,
#  'interview': 2,
#  'baksa': 1,
#  'heist': 1,
#  'selaru': 1,
#  'pinker': 1,
#  'provincepopulated': 1,
#  'libyaksourformer': 1,
#  'sweet': 2,
#  'maegashira': 1,
#  'comandante': 1,
#  'pochyta': 1,
#  'نالوت': 1,
#  'maria': 4,
#  'charlton': 1,
#  'norton': 1,
#  'pozoblanco': 1,
#  'motion': 1,
#  'innovation': 2,
#  'galápagos': 1,
#  'sabari': 1,
#  'dominique': 1,
#  'recipient': 1,
#  'swimming': 1,
#  'frederiksø': 1,
#  'canyamars': 1,
#  'alpes': 1,
#  'marri': 1,
#  'topographic': 1,
#  'jasper': 2,
#  'empire': 1,
#  'channel': 2,
#  'karshi': 1,
#  'friday': 2,
#  'robinson': 1,
#  'hoosiers': 1,
#  'aylon': 1,
#  'slovakia': 1,
#  'biblical': 1,
#  'orscher': 1,
#  'cosmopterix': 1,
#  'jevons': 1,
#  'expatriates': 1,
#  'rabbinic': 1,
#  'midland': 1,
#  'bradford': 1,
#  'canoe': 1,
#  'uruguay': 1,
#  'coffey': 1,
#  '96972': 1,
#  'tbilisi': 1,
#  'documented': 1,
#  'panna': 1,
#  'mitrella': 1,
#  'scotland': 4,
#  'acacia': 1,
#  'mostly': 1,
#  'żebry': 1,
#  'chronicles': 1,
#  'conspiracy': 1,
#  'papyrus': 1,
#  'uncredited': 1,
#  'bristol': 1,
#  'article': 93,
#  'pathogens': 1,
#  'odoacer': 1,
#  'assembly': 11,
#  'clubssport': 1,
#  'kerala': 2,
#  'taibnet': 1,
#  'sauces': 2,
#  'april': 37,
#  'gmina': 6,
#  'bivalvia': 1,
#  'aragón': 1,
#  'attributed': 1,
#  'beekeeping': 1,
#  'berzeliustinden': 1,
#  'playstation': 1,
#  'published': 11,
#  'deprecated': 3,
#  'insurance': 1,
#  'westminster': 1,
#  'mortes': 1,
#  'large': 5,
#  'pinguins': 1,
#  'mycenae': 1,
#  'beenie': 1,
#  'surfaced': 1,
#  'syncretocarpus': 1,
#  'athenaeus': 1,
#  'mehrabad': 1,
#  'tubau': 1,
#  'interstellar': 1,
#  'kristian': 1,
#  'constable': 1,
#  'england': 14,
#  'museum': 12,
#  'golightly': 1,
#  'salle': 2,
#  'dermatophylla': 1,
#  'their': 32,
#  'infanterie': 1,
#  'podcasting': 1,
#  'uttar': 2,
#  'ceiling': 1,
#  'cliff': 1,
#  'fencing': 1,
#  'lubowicz': 1,
#  'never': 1,
#  'pacific': 5,
#  'pinafore': 1,
#  'diplomat': 1,
#  'smith': 6,
#  'cancer': 2,
#  'dance': 3,
#  'darvazeh': 1,
#  'reward': 1,
#  'denis': 1,
#  'golabkhvaran': 1,
#  'irish': 5,
#  'kōriyama': 1,
#  'translated': 5,
#  'throw': 1,
#  'bahrain': 1,
#  'temples': 2,
#  'footscray': 1,
#  'sourcearticles': 2,
#  'monaco': 1,
#  'producer': 5,
#  'rolán': 1,
#  'stratford': 1,
#  'furto': 1,
#  'freeman': 1,
#  'greater': 2,
#  'newspaper': 1,
#  'accompany': 1,
#  'suckers': 1,
#  'boulevard': 1,
#  'vilnius': 1,
#  'kamakshyanagar': 1,
#  'mccaffer': 1,
#  'kinabalu': 1,
#  'brașov': 1,
#  'lasse': 1,
#  'adult': 3,
#  'delhi': 1,
#  'cooper': 2,
#  'vineyards': 1,
#  'kings': 2,
#  'dedication': 1,
#  'sultanate': 1,
#  'danes': 1,
#  'conservative': 4,
#  '03444': 1,
#  'regionalne': 1,
#  'vostochny': 1,
#  'preceding': 1,
#  '78278': 1,
#  'maukala': 1,
#  'whitley': 1,
#  'enteropathy': 1,
#  'indian': 10,
#  'since': 3,
#  'towns': 2,
#  'interest': 2,
#  'maurice': 2,
#  'abbeville': 1,
#  'francesco': 1,
#  'including': 7,
#  'wetangula': 1,
#  'sagrai': 1,
#  'jordan_steel': 1,
#  '2776694': 1,
#  '74583': 1,
#  'frederick': 2,
#  'sammy': 1,
#  'oldid': 13,
#  'crown': 2,
#  'incidents': 2,
#  'dwight': 1,
#  'referencewikipedia': 1,
#  'shibanov': 1,
#  'parties': 7,
#  'fagin': 1,
#  'extremadura': 1,
#  'sweeper': 1,
#  'cells': 1,
#  'senapati': 1,
#  'representing': 1,
#  'banovinas': 1,
#  'gamede': 1,
#  'boerne': 1,
#  'awhum': 1,
#  'museums': 2,
#  'nanjing': 1,
#  'pubmed': 2,
#  'labelle': 1,
#  'vivie': 1,
#  'bathurst': 1,
#  'merchant': 1,
#  'donovan': 1,
#  'birkenhead': 1,
#  'multnomah': 1,
#  'mengs': 1,
#  'resolution': 3,
#  'nights': 1,
#  'malay': 2,
#  'hungarian': 2,
#  'bible': 1,
#  'neighborhood': 3,
#  'latin': 6,
#  'completed': 1,
#  'struttin': 1,
#  'narendran': 1,
#  'philippines': 4,
#  'carol': 1,
#  '09667': 1,
#  'cyclists': 1,
#  'alexios': 1,
#  'vijayakanth': 1,
#  '000000002012': 1,
#  'liberal': 8,
#  'hurling': 1,
#  'department': 8,
#  'monson': 1,
#  'birchall': 1,
#  'lalden': 1,
#  'waters': 2,
#  'table': 3,
#  'columbia': 9,
#  'wimberley': 1,
#  'romance': 2,
#  'thaitambon': 1,
#  'tiruchirappalli': 1,
#  'dressage': 1,
#  'henrique': 2,
#  'intended': 2,
#  'octubre': 1,
#  'famous': 3,
#  'stöver': 1,
#  'palmer': 1,
#  'garfield': 2,
#  'playersscotland': 1,
#  'kumar': 2,
#  'heaven': 2,
#  'different': 1,
#  'millot': 1,
#  'primitives': 1,
#  'mamatey': 1,
#  'estonian': 1,
#  'swing': 4,
#  'motori': 1,
#  'cyclones': 1,
#  'helix': 1,
#  'membranes': 1,
#  'maxwell': 1,
#  '94750': 1,
#  'amioun': 1,
#  'chandor': 1,
#  'receptor': 1,
#  'allows': 1,
#  'charismo': 1,
#  'needing': 6,
#  'institut': 1,
#  'tadashi': 1,
#  'oldest': 1,
#  'brazil': 2,
#  'appointed': 2,
#  'stuttgart': 1,
#  'region': 12,
#  'marshall': 2,
#  'deanery': 1,
#  'التخطيط': 1,
#  'sierra': 4,
#  'niemczyk': 1,
#  'government': 10,
#  'puebla': 1,
#  'shivaji': 1,
#  'collingwood': 1,
#  'meneng': 1,
#  'vitalic': 1,
#  'again': 4,
#  'brunswick': 1,
#  'street': 13,
#  'eggerberg': 1,
#  'music': 29,
#  'ancient': 1,
#  'finns': 1,
#  'rembong': 1,
#  'chrysops': 1,
#  'slopes': 1,
#  'marathi': 2,
#  'a1453': 1,
#  'gospels': 1,
#  'bhubaneswar': 1,
#  'kamenogorsk': 1,
#  'phorids': 1,
#  'guitars': 1,
#  'mariana': 1,
#  'kowalski': 1,
#  'moulton': 1,
#  'oriente': 1,
#  'sumba': 1,
#  'jennifer': 1,
#  'hydraulic': 1,
#  'james': 13,
#  'cinema': 1,
#  'lydia': 1,
#  'issued': 1,
#  'shorthand': 1,
#  'littoral': 1,
#  'panthers': 1,
#  'rutkjær': 1,
#  'cancrivora': 1,
#  'assam': 1,
#  'gdyel': 1,
#  'moral': 1,
#  'labrador': 2,
#  'dolphins': 1,
#  'safety': 1,
#  'pennsylvania': 3,
#  'очерки': 1,
#  'bibiana': 1,
#  'leicester': 1,
#  'north': 35,
#  'braunstein': 1,
#  'cochran': 1,
#  'caribbean': 2,
#  'ssr180711': 1,
#  'organ': 1,
#  'mandal': 1,
#  'catalunya': 1,
#  'burkart': 1,
#  'kyzyl': 1,
#  'delannoy': 1,
#  'khaki': 1,
#  'stereo': 1,
#  'midlands': 1,
#  'indicated': 1,
#  'guitar': 6,
#  'meizu': 1,
#  'methyl': 1,
#  'harry': 5,
#  'towards': 3,
#  'angiosperm': 1,
#  'educated': 1,
#  'areas': 6,
#  'simulates': 1,
#  'eugenio': 1,
#  'sacksioni': 1,
#  'pushkin': 1,
#  'movie': 6,
#  'pitcher': 2,
#  'felipe': 1,
#  'cardinal': 1,
#  '90167': 1,
#  '41528': 1,
#  'vanløse': 1,
#  'scotia': 1,
#  'walking': 1,
#  'guardian': 1,
#  'gamecube': 1,
#  '18139': 1,
#  'davis': 1,
#  'giang': 1,
#  'baronetcy': 1,
#  'bounty': 1,
#  'chiang': 1,
#  'montana': 3,
#  'palio': 1,
#  'videos': 1,
#  'screenings': 1,
#  'abanycha': 1,
#  'record': 8,
#  'sunita': 1,
#  'concerts': 1,
#  'kassel': 1,
#  'barra': 1,
#  'wheatland': 1,
#  'politically': 1,
#  'yolks': 1,
#  'build': 1,
#  'eurotiomycetes': 1,
#  'hankó': 1,
#  'rheide': 1,
#  'concord': 1,
#  'oberliga': 1,
#  'primitive': 1,
#  'toronto': 5,
#  'patch': 1,
#  'szydlice': 1,
#  'hungary': 3,
#  'christ': 1,
#  'macdonald': 1,
#  'serbia': 2,
#  'coronation': 1,
#  'yarkand': 1,
#  'gafsheh': 1,
#  'kaisertal': 1,
#  'bangor': 2,
#  'coenaculum': 1,
#  'minsk': 2,
#  'moist': 1,
#  'bayou': 1,
#  'attorney': 1,
#  'michigan': 2,
#  'stjørdal': 1,
#  'thali': 1,
#  'allies': 1,
#  'shahu': 1,
#  'madalena': 1,
#  '09194': 1,
#  'might': 1,
#  'crystal': 1,
#  'actressesgerman': 1,
#  'novgorod': 2,
#  'battle': 9,
#  'night': 2,
#  'laughin': 1,
#  'nelson': 4,
#  'overall': 1,
#  'benton': 1,
#  'nocturnal': 1,
#  'drive': 2,
#  'merriman': 1,
#  'exercise': 1,
#  'karnataka': 3,
#  'umpire': 1,
#  'spine': 1,
#  'enugu': 1,
#  'overs': 1,
#  'paralympic': 1,
#  'country': 15,
#  'harlekijn': 1,
#  'hosts': 1,
#  'second': 9,
#  'films': 7,
#  'jūryō': 1,
#  'nursery': 1,
#  'presenter': 2,
#  'raiders': 3,
#  'malchin': 1,
#  'curtiss': 1,
#  'ingelheim': 1,
#  'rhythm': 1,
#  'southern': 10,
#  'making': 1,
#  'dinamo': 2,
#  'misset': 1,
#  'caillié': 1,
#  'cycling': 1,
#  'ioana': 1,
#  'scarlet': 1,
#  'kendall': 1,
#  'chassis': 1,
#  'wildlife': 1,
#  'caius': 1,
#  'skaggs': 1,
#  '59194': 1,
#  'grenfell': 1,
#  'current': 4,
#  'titles': 4,
#  'cricinfo': 1,
#  'savitri': 1,
#  'academics': 1,
#  'commentary': 1,
#  'crotty': 1,
#  'trevor': 1,
#  'montreuil': 1,
#  'holstein': 1,
#  'raising': 1,
#  'punjabi': 1,
#  'rebellion': 1,
#  'halen': 1,
#  'montauban': 1,
#  'clegg': 2,
#  'lacking': 29,
#  'esglèsia': 1,
#  'peasant': 1,
#  'chickens': 1,
#  'knowlton': 1,
#  'davies': 2,
#  'horizon': 1,
#  'plzeň': 2,
#  'rolli': 1,
#  'darts': 1,
#  'möschler': 1,
#  'finals': 1,
#  'sverre': 1,
#  'william': 17,
#  'conte': 1,
#  'hoops': 1,
#  'giuliani': 1,
#  'freedom': 1,
#  'radkovtsi': 2,
#  'laurenti': 1,
#  'okuda': 1,
#  'melanolagus': 1,
#  'singh': 4,
#  'shown': 1,
#  'syngnathiformes': 1,
#  'biteback': 1,
#  'wausau': 1,
#  'outstanding': 1,
#  'revelry': 1,
#  'wales': 6,
#  'metres': 7,
#  'workers': 2,
#  'brewers': 1,
#  'manila': 1,
#  'frank': 1,
#  'modern': 6,
#  'bratz': 1,
#  'mahalleh': 3,
#  'selection': 1,
#  'connecticut': 1,
#  'climax': 1,
#  'julian': 1,
#  'anthologized': 1,
#  'theology': 1,
#  'robust': 1,
#  'camera': 1,
#  'covell': 1,
#  '1980miltochristanudariina': 1,
#  'trophy': 5,
#  'aperiens': 1,
#  'maunder': 1,
#  'nidovirales': 1,
#  'scout': 1,
#  'poetry': 1,
#  'ofcom': 1,
#  'sites': 3,
#  'communist': 3,
#  'komaroff': 1,
#  'blocks': 1,
#  '08444': 1,
#  'clarkes': 1,
#  'larsen': 1,
#  'nicotinic': 1,
#  'domain': 2,
#  'haryana': 1,
#  'hamconius': 1,
#  'endopeptidase': 1,
#  'chiddingstone': 1,
#  'latino': 1,
#  'noctuidae': 1,
#  '61026': 1,
#  'torreggiani': 1,
#  'reaction': 1,
#  'andhra': 1,
#  'norske': 1,
#  'september': 43,
#  'coventry': 1,
#  'entry': 1,
#  'genera': 2,
#  'pichoy': 1,
#  '840516': 1,
#  'blackburn': 1,
#  'elizabeth': 4,
#  'research': 14,
#  '20060826': 1,
#  'machine': 4,
#  'finishing': 1,
#  'santiago': 1,
#  'community': 19,
#  'johnson': 5,
#  'katowee': 1,
#  'parish': 2,
#  '3765722': 1,
#  'arčikauskas': 1,
#  'scottish': 7,
#  'exchange': 1,
#  'margaret': 2,
#  'showdown': 1,
#  'termed': 1,
#  'routine': 1,
#  'prescott': 1,
#  '76444': 1,
#  'hastings': 1,
#  'benny': 1,
#  'indicate': 1,
#  'diving': 1,
#  'located': 6,
#  'angeles': 6,
#  'fennelly': 1,
#  'songwriter': 2,
#  'ultratop': 1,
#  'hubert': 1,
#  'heald': 1,
#  'clásico': 1,
#  'synapse': 1,
#  'black': 11,
#  '89500': 1,
#  'badajoz': 1,
#  'district': 47,
#  'facilities': 3,
#  'martini': 1,
#  'chicken': 1,
#  'haraicha': 1,
#  'becky': 1,
#  'morelli': 1,
#  'facility': 1,
#  'parasitized': 1,
#  '36417': 1,
#  '086333': 1,
#  'bikers': 1,
#  'quarterfinals': 2,
#  'myponga': 1,
#  'beauty': 1,
#  'bijou': 1,
#  'isontius': 1,
#  'positions': 1,
#  'times': 13,
#  'feedjit': 1,
#  'princeton': 3,
#  'movement': 4,
#  'physician': 2,
#  'surgical': 1,
#  'missouri': 3,
#  'bericoides': 1,
#  'genes': 1,
#  'transcription': 1,
#  'blessed': 1,
#  'thakur': 1,
#  'astro': 1,
#  'bhishti': 1,
#  'synthase': 1,
#  'metal': 3,
#  'rurikids': 1,
#  'presbyterian': 1,
#  'wolfgang': 1,
#  '94611': 1,
#  'piętki': 1,
#  'pyrochta': 1,
#  'velika': 1,
#  'ameenapuram': 1,
#  'balázs': 1,
#  'frosinone': 1,
#  'acorah': 1,
#  'collins': 1,
#  'lomas': 1,
#  'template': 17,
#  '404478433': 1,
#  'currently': 1,
#  'potosí': 1,
#  'median': 5,
#  'swannington': 1,
#  'tischofer': 1,
#  'shinpei': 1,
#  'pierre': 1,
#  'enghave': 1,
#  'sabha': 1,
#  'examiner': 1,
#  'edelen': 1,
#  'hornets': 1,
#  'tommy': 1,
#  'grizzly': 2,
#  'cypriot': 1,
#  'hotel': 3,
#  'linton': 1,
#  'nemov': 1,
#  'eddie': 1,
#  'argentina': 4,
#  'birth': 18,
#  'antioquia': 1,
#  'mercury': 1,
#  'amazona': 1,
#  'concert': 3,
#  'technique': 1,
#  'mazowieckie': 1,
#  'awarded': 3,
#  'kreslyuvtsi': 1,
#  'starring': 2,
#  'figaro': 1,
#  'huddersfield': 1,
#  'health': 2,
#  'murex': 1,
#  'plectorhinchus': 1,
#  'rials': 1,
#  '916846': 1,
#  'alphonse': 1,
#  'brooke': 2,
#  'croci': 1,
#  'commission': 3,
#  'general': 21,
#  'double': 1,
#  'liberalism': 1,
#  'grand': 7,
#  'households': 3,
#  '22389': 1,
#  'odder': 1,
#  'janeiro': 1,
#  'visual': 1,
#  'livestock': 1,
#  'superorder': 1,
#  'ishikari': 1,
#  'commissioner': 2,
#  'tajuña': 1,
#  'caramagna': 1,
#  'personality': 1,
#  'homebuilt': 1,
#  'libyan': 1,
#  'fritz': 1,
#  'photographic': 3,
#  'parks': 5,
#  'taylour': 1,
#  'cárdenas': 1,
#  'avengers': 1,
#  'palestine': 1,
#  'tomohiko': 1,
#  'aurora': 1,
#  '0296216': 1,
#  'turkic': 1,
#  'convention': 1,
#  'tomislav': 1,
#  'turowo': 1,
#  'future': 1,
#  'pospisil': 1,
#  'flying': 1,
#  'bomfunk': 1,
#  'ramana': 1,
#  '31889': 1,
#  'armenian': 2,
#  'tarot': 1,
#  'moradabad': 1,
#  'français': 1,
#  'kildare': 1,
#  'unsourced': 5,
#  'sussex': 1,
#  'politician': 7,
#  'durrës': 1,
#  '12754': 1,
#  'science': 8,
#  'barloworld': 1,
#  'gloucester': 1,
#  'lanús': 1,
#  'taiwan': 2,
#  'lakes': 4,
#  'jonas': 1,
#  'fulminate': 1,
#  'election': 12,
#  ...}
